# %%
#!/usr/bin/env python3
"""
Market Screener for Grid Trading Pairs
Fetches all spot/USDT pairs from Binance and applies screening criteria
"""

import ccxt
import pandas as pd
import numpy as np
from typing import List, Dict, Optional, Tuple
from dataclasses import dataclass
from datetime import datetime, timedelta
import time
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
import json
import os
from pathlib import Path

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

@dataclass
class PairData:
    """Data structure for trading pair information"""
    symbol: str
    close_price: float
    hurst_exponent: float
    volume_7d: float
    volume_7d_usd: float
    last_update: datetime
    ohlcv_data: Optional[pd.DataFrame] = None

@dataclass
class ScreeningCriteria:
    """Screening criteria configuration with validation"""
    min_price: float = 1.0
    min_volume_7d_usd: float = 10_000_000
    max_hurst: float = 0.5  # Hurst < 0.5 for mean-reverting
    years_of_data: int = 1  # 1 year of data
    top_n_pairs: int = 5  # Top 5 pairs
    
    def __post_init__(self):
        """Validate criteria values"""
        if self.min_price <= 0:
            raise ValueError("min_price must be positive")
        if self.min_volume_7d_usd <= 0:
            raise ValueError("min_volume_7d_usd must be positive")
        if not 0 <= self.max_hurst <= 1:
            raise ValueError("max_hurst must be between 0 and 1")
        if self.years_of_data <= 0:
            raise ValueError("years_of_data must be positive")
        if self.top_n_pairs <= 0:
            raise ValueError("top_n_pairs must be positive")

class HurstCalculator:
    """Calculate Hurst exponent for time series analysis with robust error handling"""
    
    @staticmethod
    def calculate_hurst(price_series: pd.Series) -> float:
        """
        Calculate Hurst exponent using R/S analysis
        
        Args:
            price_series: Price series (typically close prices)
            
        Returns:
            Hurst exponent value (0-1, where <0.5 = mean-reverting, >0.5 = trending)
        """
        try:
            # Input validation
            if price_series is None or price_series.empty:
                logger.warning("Empty price series provided for Hurst calculation")
                return 0.5
            
            if len(price_series) < 20:  # Need at least 20 data points
                logger.warning(f"Insufficient data for Hurst calculation: {len(price_series)} points")
                return 0.5
            
            # Remove any NaN or infinite values
            clean_series = price_series.dropna()
            if len(clean_series) < 20:
                logger.warning("Insufficient clean data after removing NaN values")
                return 0.5
            
            # Calculate log returns
            log_returns = np.log(clean_series / clean_series.shift(1)).dropna()
            
            if len(log_returns) < 20:
                logger.warning("Insufficient log returns for Hurst calculation")
                return 0.5
            
            # Check for constant values (no variance)
            if log_returns.std() == 0:
                logger.warning("No variance in log returns, returning neutral Hurst")
                return 0.5
            
            # R/S analysis
            n = len(log_returns)
            mean_return = log_returns.mean()
            
            # Calculate cumulative deviations
            cumsum_deviations = (log_returns - mean_return).cumsum()
            
            # Calculate range R
            R = cumsum_deviations.max() - cumsum_deviations.min()
            
            # Calculate standard deviation S
            S = log_returns.std()
            
            if S == 0 or R == 0:
                logger.warning("Zero variance or range in R/S calculation")
                return 0.5
            
            # R/S ratio
            rs_ratio = R / S
            
            if rs_ratio <= 0:
                logger.warning("Invalid R/S ratio, returning neutral Hurst")
                return 0.5
            
            # Hurst exponent calculation
            hurst = np.log(rs_ratio) / np.log(n)
            
            # Clamp between 0 and 1
            hurst = max(0.0, min(1.0, hurst))
            
            return float(hurst)
            
        except Exception as e:
            logger.error(f"Error calculating Hurst exponent: {e}")
            return 0.5  # Return neutral value on error

class BinanceDataFetcher:
    """Enhanced data fetcher for Binance with error handling and caching"""
    
    def __init__(self, api_key: Optional[str] = None, api_secret: Optional[str] = None):
        # Configure exchange with API credentials if available
        exchange_config = {
            "enableRateLimit": True,
            "options": {"defaultType": "spot"}  # Make sure it's spot, not futures
        }
        
        # Add API credentials if provided
        if api_key and api_secret:
            exchange_config.update({
                "apiKey": api_key,
                "secret": api_secret
            })
            logger.info("🔑 Using API credentials for enhanced data access")
        else:
            logger.info("🌐 Using public endpoints only")
            
        self.exchange = ccxt.binance(exchange_config)
        self.cache_dir = Path('data_cache')
        self.cache_dir.mkdir(exist_ok=True)
 
    def get_all_spot_usdt_pairs_merged(self) -> List[str]:
        """Get all spot USDT trading pairs from Binance with API access"""
        try:
            # Load markets to get comprehensive list
            markets = self.exchange.load_markets()
            usdt_pairs = []
            
            for symbol, market in markets.items():
                if (market.get('type') == 'spot' and 
                    market.get('quote') == 'USDT' and 
                    market.get('active', False)):
                    usdt_pairs.append(symbol)
            
            if not usdt_pairs:
                logger.warning("No USDT pairs found, using fallback list")
                return self._get_fallback_pairs()
            
            logger.info(f"Found {len(usdt_pairs)} active USDT spot pairs")
            
            # Sort by volume for better prioritization (only if we have API access)
            try:
                merged_usdt_pairs = []
                total_pairs = len(usdt_pairs)
                batch_size = 100

                for i in range(0, total_pairs, batch_size):
                    top_pairs = usdt_pairs[i:i+batch_size]
                    tickers = self.exchange.fetch_tickers(top_pairs)
                    merged_usdt_pairs.extend(top_pairs)
                    logger.info(f"Fetched batch {i//batch_size+1}: {len(top_pairs)} pairs")
                    time.sleep(3)  # Sleep to avoid rate limit

                # Sort merged_usdt_pairs by trading volume at the end
                all_tickers = self.exchange.fetch_tickers(merged_usdt_pairs)
                usdt_pairs = sorted(merged_usdt_pairs, key=lambda x: all_tickers.get(x, {}).get('quoteVolume', 0), reverse=True)
                logger.info("Merged and sorted all pairs by trading volume")

            except Exception as e:
                logger.warning(f"Could not sort by volume: {e}")
            
            return usdt_pairs
            
        except Exception as e:
            logger.error(f"Error fetching spot pairs: {e}")
            return self._get_fallback_pairs()
           
    def get_all_spot_usdt_pairs(self) -> List[str]:
        """Get all spot USDT trading pairs from Binance with API access"""
        try:
            # Load markets to get comprehensive list
            markets = self.exchange.load_markets()
            usdt_pairs = []
            
            for symbol, market in markets.items():
                if (market.get('type') == 'spot' and 
                    market.get('quote') == 'USDT' and 
                    market.get('active', False)):
                    usdt_pairs.append(symbol)
            
            if not usdt_pairs:
                logger.warning("No USDT pairs found, using fallback list")
                return self._get_fallback_pairs()
            
            logger.info(f"Found {len(usdt_pairs)} active USDT spot pairs")
            
            # Sort by volume for better prioritization (only if we have API access)
            try:
                # Limit to top 100 pairs to avoid rate limits
                # top_pairs = usdt_pairs[:100]
                # top_pairs = usdt_pairs[100:200]
                top_pairs = usdt_pairs[200:300]
                # top_pairs = usdt_pairs[300:400]
                # top_pairs = usdt_pairs[400:419]

                tickers = self.exchange.fetch_tickers(top_pairs)
                usdt_pairs.sort(key=lambda x: tickers.get(x, {}).get('quoteVolume', 0), reverse=True)
                logger.info("Sorted pairs by trading volume")
            except Exception as e:
                logger.warning(f"Could not sort by volume: {e}")
            
            return usdt_pairs
            
        except Exception as e:
            logger.error(f"Error fetching spot pairs: {e}")
            return self._get_fallback_pairs()
    
    def _get_fallback_pairs(self) -> List[str]:
        """Get fallback list of major USDT pairs"""
        logger.info("Using fallback list of major USDT pairs")
        return [
            'BTC/USDT', 'ETH/USDT', 'BNB/USDT', 'ADA/USDT', 'XRP/USDT',
            'SOL/USDT', 'DOT/USDT', 'DOGE/USDT', 'AVAX/USDT', 'SHIB/USDT',
            'MATIC/USDT', 'LTC/USDT', 'UNI/USDT', 'LINK/USDT', 'ATOM/USDT',
            'XLM/USDT', 'BCH/USDT', 'FIL/USDT', 'TRX/USDT', 'ETC/USDT',
            'VET/USDT', 'ICP/USDT', 'THETA/USDT', 'FTM/USDT', 'ALGO/USDT',
            'MANA/USDT', 'SAND/USDT', 'AXS/USDT', 'CRV/USDT', 'COMP/USDT',
            'MKR/USDT', 'SNX/USDT', 'YFI/USDT', 'AAVE/USDT', 'SUSHI/USDT'
        ]
    
    def fetch_ohlcv_data(self, symbol: str, timeframe: str = '1d', 
                        years: int = 1) -> Optional[pd.DataFrame]:
        """Fetch OHLCV data for a symbol with caching and robust error handling"""
        try:
            # Input validation
            if not symbol or not isinstance(symbol, str):
                logger.error(f"Invalid symbol: {symbol}")
                return None
            
            if years <= 0 or years > 5:  # Limit to reasonable range
                logger.warning(f"Invalid years parameter: {years}, using 1 year")
                years = 1
            
            # Check cache first
            cache_file = self.cache_dir / f"{symbol.replace('/', '_')}_{timeframe}_{years}y.json"
            
            if cache_file.exists():
                cache_time = datetime.fromtimestamp(cache_file.stat().st_mtime)
                if datetime.now() - cache_time < timedelta(hours=1):  # Cache valid for 1 hour
                    logger.info(f"Loading {symbol} from cache")
                    try:
                        with open(cache_file, 'r') as f:
                            data = json.load(f)
                            df = pd.DataFrame(data)
                            if not df.empty:
                                return df
                    except Exception as e:
                        logger.warning(f"Error loading cache for {symbol}: {e}")
            
            # Calculate start date for historical data
            end_date = datetime.now()
            start_date = end_date - timedelta(days=years * 365)
            
            # Convert to timestamp
            from_ts = self.exchange.parse8601(start_date.strftime('%Y-%m-%d %H:%M:%S'))
            
            # Fetch data with pagination
            ohlcv_list = self._fetch_ohlcv_paginated(symbol, timeframe, from_ts)
            
            if not ohlcv_list:
                logger.warning(f"No data fetched for {symbol}")
                return None
            
            # Convert to DataFrame
            df = pd.DataFrame(ohlcv_list, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
            df = df.sort_values('timestamp').drop_duplicates(subset=['timestamp'])
            df = df.reset_index(drop=True)
            
            # Validate data quality
            if len(df) < 30:  # Need at least 30 days
                logger.warning(f"Insufficient data for {symbol}: {len(df)} days")
                return None
            
            # Cache the data
            try:
                with open(cache_file, 'w') as f:
                    json.dump(df.to_dict('records'), f, default=str)
            except Exception as e:
                logger.warning(f"Error caching data for {symbol}: {e}")
            
            logger.info(f"Fetched {len(df)} candles for {symbol}")
            return df
            
        except Exception as e:
            logger.error(f"Error fetching OHLCV for {symbol}: {e}")
            return None
    
    def _fetch_ohlcv_paginated(self, symbol: str, timeframe: str, from_ts: int) -> List:
        """Fetch OHLCV data with pagination and rate limiting"""
        ohlcv_list = []
        max_candles = 1000  # Reasonable limit for 1 year of daily data
        
        try:
            # First request
            ohlcv = self.exchange.fetch_ohlcv(symbol, timeframe, since=from_ts, limit=1000)
            if ohlcv:
                ohlcv_list.extend(ohlcv)
            
            # Pagination loop
            while len(ohlcv_list) < max_candles:
                if not ohlcv or len(ohlcv) < 1000:
                    break
                
                # Get the last timestamp and request next batch
                from_ts = ohlcv[-1][0] + 1  # Add 1ms to avoid duplicates
                ohlcv = self.exchange.fetch_ohlcv(symbol, timeframe, since=from_ts, limit=1000)
                
                if not ohlcv or len(ohlcv) == 0:
                    break
                
                ohlcv_list.extend(ohlcv)
                
                # Rate limiting
                time.sleep(0.1)
                
                # Safety check
                if len(ohlcv_list) > max_candles:
                    ohlcv_list = ohlcv_list[:max_candles]
                    break
            
            return ohlcv_list
            
        except Exception as e:
            logger.warning(f"Error in pagination for {symbol}: {e}")
            return ohlcv_list
    
    def get_current_ticker_data(self, symbol: str) -> Optional[Dict]:
        """Get current ticker data for a symbol using the exact pattern from your example"""
        try:
            ticker = self.exchange.fetch_ticker(symbol)
            return ticker
        except Exception as e:
            logger.warning(f"Error fetching ticker for {symbol}: {e}")
            return None
    
    def calculate_volume_7d_usd(self, df: pd.DataFrame) -> float:
        """Calculate 7-day trading volume in USD with validation"""
        try:
            if df is None or df.empty:
                logger.warning("Empty DataFrame provided for volume calculation")
                return 0.0
            
            if len(df) < 7:
                logger.warning(f"Insufficient data for 7d volume calculation: {len(df)} days")
                return 0.0
            
            # Validate required columns
            required_cols = ['volume', 'close']
            if not all(col in df.columns for col in required_cols):
                logger.error(f"Missing required columns: {required_cols}")
                return 0.0
            
            # Get last 7 days of data
            last_7_days = df.tail(7)
            
            # Check for valid data
            if last_7_days['volume'].isna().any() or last_7_days['close'].isna().any():
                logger.warning("NaN values found in volume or close data")
                return 0.0
            
            # Calculate volume in USD (volume * close_price)
            volume_usd = (last_7_days['volume'] * last_7_days['close']).sum()
            
            # Validate result
            if volume_usd < 0:
                logger.warning("Negative volume calculated, returning 0")
                return 0.0
            
            return float(volume_usd)
            
        except Exception as e:
            logger.error(f"Error calculating 7d volume: {e}")
            return 0.0

class MarketScreener:
    """Main market screener class - clean and simple"""
    
    def __init__(self, api_key: Optional[str] = None, api_secret: Optional[str] = None):
        self.data_fetcher = BinanceDataFetcher(api_key, api_secret)
        self.hurst_calculator = HurstCalculator()
        self.criteria = ScreeningCriteria()
        self.results: List[PairData] = []
        
    def screen_single_pair(self, symbol: str) -> Optional[PairData]:
        """Screen a single trading pair with comprehensive validation and error handling"""
        try:
            # Input validation
            if not symbol or not isinstance(symbol, str):
                logger.error(f"Invalid symbol: {symbol}")
                return None
            
            logger.info(f"Screening {symbol}...")
            
            # Step 1: Get current ticker data for quick filters
            ticker_data = self.data_fetcher.get_current_ticker_data(symbol)
            if not ticker_data:
                logger.warning(f"No ticker data available for {symbol}")
                return None
            
            # Step 2: Price filter (quick)
            current_price = ticker_data.get('last', 0)
            if current_price <= 0:
                logger.warning(f"Invalid price for {symbol}: {current_price}")
                return None
            
            if current_price < self.criteria.min_price:
                logger.debug(f"{symbol} filtered out: price ${current_price:.4f} < ${self.criteria.min_price}")
                return None
            
            # Step 3: Volume pre-filter (quick)
            volume_24h = ticker_data.get('quoteVolume', 0)
            if volume_24h <= 0:
                logger.warning(f"Invalid volume for {symbol}: {volume_24h}")
                return None
            
            # Quick volume check (24h volume * 7 should be roughly 7d volume)
            estimated_7d_volume = volume_24h * 7
            if estimated_7d_volume < self.criteria.min_volume_7d_usd * 0.5:  # Conservative estimate
                logger.debug(f"{symbol} filtered out: estimated 7d volume ${estimated_7d_volume:,.0f} too low")
                return None
            
            # Step 4: Fetch OHLCV data for detailed analysis
            df = self.data_fetcher.fetch_ohlcv_data(symbol, years=self.criteria.years_of_data)
            if df is None or df.empty:
                logger.warning(f"No OHLCV data available for {symbol}")
                return None
            
            # Step 5: Data quality check
            if len(df) < 30:  # At least 30 days of data
                logger.warning(f"Insufficient data for {symbol}: {len(df)} days")
                return None
            
            # Step 6: Calculate 7-day volume in USD (detailed check)
            volume_7d_usd = self.data_fetcher.calculate_volume_7d_usd(df)
            if volume_7d_usd < self.criteria.min_volume_7d_usd:
                logger.debug(f"{symbol} filtered out: 7d volume ${volume_7d_usd:,.0f} < ${self.criteria.min_volume_7d_usd:,.0f}")
                return None
            
            # Step 7: Calculate Hurst exponent
            hurst = self.hurst_calculator.calculate_hurst(df['close'])
            if hurst >= self.criteria.max_hurst:
                logger.debug(f"{symbol} filtered out: Hurst {hurst:.4f} >= {self.criteria.max_hurst}")
                return None
            
            # Step 8: Calculate 7-day volume in base currency
            volume_7d = df.tail(7)['volume'].sum()
            
            # Step 9: Create pair data
            pair_data = PairData(
                symbol=symbol,
                close_price=current_price,
                hurst_exponent=hurst,
                volume_7d=volume_7d,
                volume_7d_usd=volume_7d_usd,
                last_update=datetime.now(),
                ohlcv_data=df
            )
            
            logger.info(f"✅ {symbol} passed all filters: "
                       f"Price=${current_price:.4f}, "
                       f"Hurst={hurst:.4f}, "
                       f"7d Volume=${volume_7d_usd:,.0f}")
            
            return pair_data
            
        except Exception as e:
            logger.error(f"Error screening {symbol}: {e}")
            return None
    
    def screen_all_pairs(self, max_workers: int = 3) -> List[PairData]:
        """Screen all USDT spot pairs with parallel processing and comprehensive error handling"""
        try:
            # Input validation
            if max_workers <= 0 or max_workers > 10:
                logger.warning(f"Invalid max_workers: {max_workers}, using 3")
                max_workers = 3
            
            # Get all USDT pairs
            pairs = self.data_fetcher.get_all_spot_usdt_pairs()
            # pairs = self.data_fetcher.get_all_spot_usdt_pairs_merged()
            
            if not pairs:
                logger.error("No pairs found to screen")
                return []
            
            # Limit pairs for performance (focus on top liquid pairs)
            max_pairs = 50  # Screen top 50 most liquid pairs
            if len(pairs) > max_pairs:
                pairs = pairs[:max_pairs]
                logger.info(f"Limited screening to top {max_pairs} most liquid pairs")
            
            logger.info(f"Starting screening of {len(pairs)} pairs with {max_workers} workers...")
            
            # Screen pairs in parallel
            results = []
            completed = 0
            total = len(pairs)
            
            with ThreadPoolExecutor(max_workers=max_workers) as executor:
                # Submit all tasks
                future_to_pair = {
                    executor.submit(self.screen_single_pair, pair): pair 
                    for pair in pairs
                }
                
                # Process completed tasks
                for future in as_completed(future_to_pair):
                    pair = future_to_pair[future]
                    completed += 1
                    
                    try:
                        result = future.result(timeout=30)  # 30 second timeout per pair
                        if result:
                            results.append(result)
                            logger.info(f"Progress: {completed}/{total} - Found {len(results)} valid pairs")
                    except Exception as e:
                        logger.error(f"Error processing {pair}: {e}")
                        continue
                    
                    # Progress update every 10 pairs
                    if completed % 10 == 0:
                        logger.info(f"Progress: {completed}/{total} pairs processed")
            
            # Sort by volume (descending) and take top N
            results.sort(key=lambda x: x.volume_7d_usd, reverse=True)
            top_results = results[:self.criteria.top_n_pairs]
            
            self.results = top_results
            logger.info(f"Screening completed. {len(results)} pairs passed filters.")
            logger.info(f"Top {len(top_results)} pairs selected.")
            
            return top_results
            
        except Exception as e:
            logger.error(f"Error in screening process: {e}")
            return []

    def screen_all_pairs_merged(self, max_workers: int = 3) -> List[PairData]:
        """Screen all USDT spot pairs with parallel processing and comprehensive error handling"""
        try:
            # Input validation
            if max_workers <= 0 or max_workers > 10:
                logger.warning(f"Invalid max_workers: {max_workers}, using 3")
                max_workers = 3
            
            # Get all USDT pairs
            # pairs = self.data_fetcher.get_all_spot_usdt_pairs()
            pairs = self.data_fetcher.get_all_spot_usdt_pairs_merged()
            
            if not pairs:
                logger.error("No pairs found to screen")
                return []
            
            # Process pairs in batches of 50 for performance
            batch_size = 50
            results = []
            total = len(pairs)
            completed = 0

            for batch_start in range(0, total, batch_size):
                batch_pairs = pairs[batch_start:batch_start + batch_size]
                logger.info(f"Processing batch {batch_start // batch_size + 1}: {len(batch_pairs)} pairs")

                with ThreadPoolExecutor(max_workers=max_workers) as executor:
                    future_to_pair = {
                        executor.submit(self.screen_single_pair, pair): pair
                        for pair in batch_pairs
                    }

                    for future in as_completed(future_to_pair):
                        pair = future_to_pair[future]
                        completed += 1
                        try:
                            result = future.result(timeout=30)
                            if result:
                                results.append(result)
                                logger.info(f"Progress: {completed}/{total} - Found {len(results)} valid pairs")
                        except Exception as e:
                            logger.error(f"Error processing {pair}: {e}")
                            continue

                        if completed % 10 == 0:
                            logger.info(f"Progress: {completed}/{total} pairs processed")
                            
            # Sort by volume (descending) and take top N
            results.sort(key=lambda x: x.volume_7d_usd, reverse=True)
            top_results = results[:self.criteria.top_n_pairs]
            
            self.results = top_results
            logger.info(f"Screening completed. {len(results)} pairs passed filters.")
            logger.info(f"Top {len(top_results)} pairs selected.")
            
            return top_results
            
        except Exception as e:
            logger.error(f"Error in screening process: {e}")
            return []

    def get_screening_summary(self) -> Dict:
        """Get summary of screening results"""
        if not self.results:
            return {"message": "No results available"}
        
        summary = {
            "total_pairs_screened": len(self.results),
            "criteria": {
                "min_price": self.criteria.min_price,
                "min_volume_7d_usd": self.criteria.min_volume_7d_usd,
                "max_hurst": self.criteria.max_hurst,
                "years_of_data": self.criteria.years_of_data
            },
            "top_pairs": []
        }
        
        for i, pair in enumerate(self.results, 1):
            summary["top_pairs"].append({
                "rank": i,
                "symbol": pair.symbol,
                "close_price": pair.close_price,
                "hurst_exponent": pair.hurst_exponent,
                "volume_7d_usd": pair.volume_7d_usd,
                "volume_7d": pair.volume_7d
            })
        
        return summary
    
    def save_results(self, filename: str = "screening_results.json"):
        """Save screening results to file"""
        try:
            results_data = {
                "timestamp": datetime.now().isoformat(),
                "summary": self.get_screening_summary(),
                "detailed_results": []
            }
            
            for pair in self.results:
                results_data["detailed_results"].append({
                    "symbol": pair.symbol,
                    "close_price": pair.close_price,
                    "hurst_exponent": pair.hurst_exponent,
                    "volume_7d_usd": pair.volume_7d_usd,
                    "volume_7d": pair.volume_7d,
                    "last_update": pair.last_update.isoformat()
                })
            
            with open(filename, 'w') as f:
                json.dump(results_data, f, indent=2, default=str)
            
            logger.info(f"Results saved to {filename}")
            
        except Exception as e:
            logger.error(f"Error saving results: {e}")

def main():
    """Main function to run the market screener - clean and simple"""
    try:
        logger.info("🚀 Starting Market Screener for Grid Trading Pairs")
        logger.info("=" * 60)
        
        # Load API credentials
        api_key, api_secret = _load_api_credentials()
        
        # Initialize screener
        screener = MarketScreener(api_key=api_key, api_secret=api_secret)
        
        # Run screening
        start_time = time.time()
        # results = screener.screen_all_pairs(max_workers=3)
        results = screener.screen_all_pairs_merged(max_workers=3)
        
        end_time = time.time()
        duration = end_time - start_time
        
        # Display results
        _display_results(results, duration)
        
        # Save results
        screener.save_results()
        
        # Display summary
        _display_summary(screener)
        
    except KeyboardInterrupt:
        logger.info("\n⏹️  Screening interrupted by user")
    except Exception as e:
        logger.error(f"❌ Fatal error in main: {e}")
        raise

def _load_api_credentials() -> Tuple[Optional[str], Optional[str]]:
    """Load API credentials with error handling"""
    try:
        from api_config import get_api_credentials
        api_key, api_secret = get_api_credentials()
        
        if not api_key or not api_secret:
            logger.error("❌ API credentials not configured!")
            logger.info("Please update api_config.py with your Binance API credentials")
            return None, None
        else:
            logger.info("✅ API credentials loaded successfully")
            return api_key, api_secret
            
    except ImportError:
        logger.warning("⚠️  api_config.py not found, running without API credentials")
        return None, None

def _display_results(results: List[PairData], duration: float) -> None:
    """Display screening results"""
    logger.info(f"\n⏱️  Screening completed in {duration:.2f} seconds")
    logger.info(f"📊 Found {len(results)} pairs that passed all criteria")
    
    if results:
        logger.info("\n🏆 TOP PAIRS FOR GRID TRADING:")
        logger.info("-" * 60)
        
        for i, pair in enumerate(results, 1):
            logger.info(f"{i}. {pair.symbol}")
            logger.info(f"   💰 Price: ${pair.close_price:.4f}")
            logger.info(f"   📈 Hurst: {pair.hurst_exponent:.4f}")
            logger.info(f"   💵 7d Volume: ${pair.volume_7d_usd:,.0f}")
            logger.info(f"   📊 7d Volume (base): {pair.volume_7d:,.2f}")
            logger.info("")
    else:
        logger.warning("❌ No pairs found that meet the criteria")

def _display_summary(screener: MarketScreener) -> None:
    """Display screening summary"""
    summary = screener.get_screening_summary()
    if "criteria" in summary:
        logger.info("📋 SCREENING SUMMARY:")
        logger.info(f"   Min Price: ${summary['criteria']['min_price']}")
        logger.info(f"   Min 7d Volume: ${summary['criteria']['min_volume_7d_usd']:,.0f}")
        logger.info(f"   Max Hurst: {summary['criteria']['max_hurst']}")
        logger.info(f"   Data Period: {summary['criteria']['years_of_data']} years")

if __name__ == "__main__":
    main()
# Out:
# 2025-09-22 01:58:05,199 - INFO - 🚀 Starting Market Screener for Grid Trading Pairs
# 2025-09-22 01:58:05,200 - INFO - ============================================================
# 2025-09-22 01:58:05,201 - INFO - ✅ API credentials loaded successfully
# 2025-09-22 01:58:05,202 - INFO - 🔑 Using API credentials for enhanced data access
# 2025-09-22 01:58:07,407 - INFO - Found 419 active USDT spot pairs
# 2025-09-22 01:58:07,489 - INFO - Fetched batch 1: 100 pairs
# 2025-09-22 01:58:10,574 - INFO - Fetched batch 2: 100 pairs
# 2025-09-22 01:58:13,659 - INFO - Fetched batch 3: 100 pairs
# 2025-09-22 01:58:16,743 - INFO - Fetched batch 4: 100 pairs
# 2025-09-22 01:58:19,822 - INFO - Fetched batch 5: 19 pairs
# 2025-09-22 01:58:22,944 - INFO - Merged and sorted all pairs by trading volume
# 2025-09-22 01:58:22,945 - INFO - Processing batch 1: 50 pairs
# 2025-09-22 01:58:22,946 - INFO - Screening ETH/USDT...
# 2025-09-22 01:58:22,947 - INFO - Screening USDC/USDT...
# 2025-09-22 01:58:22,948 - INFO - Screening OPEN/USDT...
# 2025-09-22 01:58:23,020 - INFO - Loading ETH/USDT from cache
# 2025-09-22 01:58:23,027 - INFO - Screening BTC/USDT...
# 2025-09-22 01:58:23,063 - INFO - Screening AVNT/USDT...
# 2025-09-22 01:58:23,096 - INFO - Screening SOL/USDT...
# 2025-09-22 01:58:23,104 - INFO - Loading BTC/USDT from cache
# 2025-09-22 01:58:23,108 - INFO - Screening BNB/USDT...
# 2025-09-22 01:58:23,196 - INFO - Loading BNB/USDT from cache
# 2025-09-22 01:58:23,199 - INFO - Screening DOGE/USDT...
# 2025-09-22 01:58:23,202 - INFO - Loading SOL/USDT from cache
# 2025-09-22 01:58:23,206 - INFO - Screening WLFI/USDT...
# 2025-09-22 01:58:23,219 - WARNING - Insufficient data for AVNT/USDT: 8 days
# 2025-09-22 01:58:23,219 - WARNING - No OHLCV data available for AVNT/USDT
# 2025-09-22 01:58:23,220 - INFO - Screening FDUSD/USDT...
# 2025-09-22 01:58:23,275 - INFO - Screening XRP/USDT...
# 2025-09-22 01:58:23,296 - INFO - Screening LINEA/USDT...
# 2025-09-22 01:58:23,299 - INFO - Screening THE/USDT...
# 2025-09-22 01:58:23,299 - INFO - Progress: 10/419 pairs processed
# 2025-09-22 01:58:23,349 - INFO - Loading XRP/USDT from cache
# 2025-09-22 01:58:23,352 - INFO - Screening PUMP/USDT...
# 2025-09-22 01:58:23,370 - INFO - Screening AVAX/USDT...
# 2025-09-22 01:58:23,392 - INFO - Screening TRX/USDT...
# 2025-09-22 01:58:23,436 - INFO - Screening SUI/USDT...
# 2025-09-22 01:58:23,447 - INFO - Loading AVAX/USDT from cache
# 2025-09-22 01:58:23,451 - INFO - Screening PEPE/USDT...
# 2025-09-22 01:58:23,467 - INFO - Screening ADA/USDT...
# 2025-09-22 01:58:23,513 - INFO - Loading SUI/USDT from cache
# 2025-09-22 01:58:23,516 - INFO - Screening ENA/USDT...
# 2025-09-22 01:58:23,529 - INFO - Screening BARD/USDT...
# 2025-09-22 01:58:23,551 - INFO - Screening LINK/USDT...
# 2025-09-22 01:58:23,592 - INFO - Screening SOMI/USDT...
# 2025-09-22 01:58:23,592 - INFO - Progress: 20/419 pairs processed
# 2025-09-22 01:58:23,613 - INFO - Screening ZKC/USDT...
# 2025-09-22 01:58:23,643 - INFO - Loading LINK/USDT from cache
# 2025-09-22 01:58:23,646 - INFO - Screening WLD/USDT...
# 2025-09-22 01:58:23,686 - INFO - Screening PENGU/USDT...
# 2025-09-22 01:58:23,747 - WARNING - Insufficient data for SOMI/USDT: 21 days
# 2025-09-22 01:58:23,748 - WARNING - No OHLCV data available for SOMI/USDT
# 2025-09-22 01:58:23,748 - INFO - Screening LISTA/USDT...
# 2025-09-22 01:58:23,756 - INFO - Loading WLD/USDT from cache
# 2025-09-22 01:58:23,759 - INFO - Screening AEVO/USDT...
# 2025-09-22 01:58:23,764 - INFO - Screening TWT/USDT...
# 2025-09-22 01:58:23,825 - INFO - Screening ARB/USDT...
# 2025-09-22 01:58:23,843 - INFO - Loading TWT/USDT from cache
# 2025-09-22 01:58:23,846 - INFO - Screening VANA/USDT...
# 2025-09-22 01:58:23,847 - INFO - Screening TUT/USDT...
# 2025-09-22 01:58:23,914 - INFO - Screening LTC/USDT...
# 2025-09-22 01:58:23,914 - INFO - Progress: 30/419 pairs processed
# 2025-09-22 01:58:23,941 - INFO - Screening SUN/USDT...
# 2025-09-22 01:58:23,974 - INFO - Loading VANA/USDT from cache
# 2025-09-22 01:58:23,978 - INFO - Screening DEXE/USDT...
# 2025-09-22 01:58:24,016 - INFO - Screening NEAR/USDT...
# 2025-09-22 01:58:24,018 - INFO - Loading LTC/USDT from cache
# 2025-09-22 01:58:24,021 - INFO - Screening EDU/USDT...
# 2025-09-22 01:58:24,063 - INFO - Loading DEXE/USDT from cache
# 2025-09-22 01:58:24,066 - INFO - Screening HOLO/USDT...
# 2025-09-22 01:58:24,091 - INFO - Loading NEAR/USDT from cache
# 2025-09-22 01:58:24,094 - INFO - Screening CAKE/USDT...
# 2025-09-22 01:58:24,135 - INFO - Screening ME/USDT...
# 2025-09-22 01:58:24,140 - INFO - Screening SEI/USDT...
# 2025-09-22 01:58:24,171 - INFO - Loading CAKE/USDT from cache
# 2025-09-22 01:58:24,174 - INFO - Screening UNI/USDT...
# 2025-09-22 01:58:24,231 - INFO - Screening BB/USDT...
# 2025-09-22 01:58:24,231 - INFO - Progress: 40/419 pairs processed
# 2025-09-22 01:58:24,232 - INFO - Screening DOT/USDT...
# 2025-09-22 01:58:24,250 - INFO - Loading UNI/USDT from cache
# 2025-09-22 01:58:24,253 - INFO - Screening APT/USDT...
# 2025-09-22 01:58:24,307 - INFO - Screening TRUMP/USDT...
# 2025-09-22 01:58:24,332 - INFO - Loading DOT/USDT from cache
# 2025-09-22 01:58:24,339 - INFO - Screening HOOK/USDT...
# 2025-09-22 01:58:24,372 - INFO - Loading APT/USDT from cache
# 2025-09-22 01:58:24,376 - INFO - Screening EIGEN/USDT...
# 2025-09-22 01:58:24,384 - INFO - Loading TRUMP/USDT from cache
# 2025-09-22 01:58:24,388 - INFO - Screening BONK/USDT...
# 2025-09-22 01:58:24,417 - INFO - Screening ONDO/USDT...
# 2025-09-22 01:58:24,459 - INFO - Loading EIGEN/USDT from cache
# 2025-09-22 01:58:24,493 - INFO - Progress: 50/419 pairs processed
# 2025-09-22 01:58:24,495 - INFO - Processing batch 2: 50 pairs
# 2025-09-22 01:58:24,496 - INFO - Screening SHIB/USDT...
# 2025-09-22 01:58:24,496 - INFO - Screening WIF/USDT...
# 2025-09-22 01:58:24,497 - INFO - Screening HBAR/USDT...
# 2025-09-22 01:58:24,573 - INFO - Screening PERP/USDT...
# 2025-09-22 01:58:24,593 - INFO - Screening FORM/USDT...
# 2025-09-22 01:58:24,595 - INFO - Screening BERA/USDT...
# 2025-09-22 01:58:24,648 - INFO - Screening CRV/USDT...
# 2025-09-22 01:58:24,722 - INFO - Screening BIO/USDT...
# 2025-09-22 01:58:24,778 - INFO - Fetched 188 candles for FORM/USDT
# 2025-09-22 01:58:24,781 - INFO - Screening LA/USDT...
# 2025-09-22 01:58:24,781 - INFO - Fetched 229 candles for BERA/USDT
# 2025-09-22 01:58:24,785 - INFO - Screening AAVE/USDT...
# 2025-09-22 01:58:24,800 - INFO - Screening DYDX/USDT...
# 2025-09-22 01:58:24,860 - INFO - Screening W/USDT...
# 2025-09-22 01:58:24,889 - INFO - Screening ETHFI/USDT...
# 2025-09-22 01:58:24,889 - INFO - Progress: 60/419 pairs processed
# 2025-09-22 01:58:24,942 - INFO - Screening OP/USDT...
# 2025-09-22 01:58:24,977 - INFO - Loading ETHFI/USDT from cache
# 2025-09-22 01:58:24,981 - INFO - Screening XLM/USDT...
# 2025-09-22 01:58:25,025 - INFO - Screening MITO/USDT...
# 2025-09-22 01:58:25,057 - INFO - Screening TST/USDT...
# 2025-09-22 01:58:25,100 - INFO - Screening ETC/USDT...
# 2025-09-22 01:58:25,138 - INFO - Screening DOLO/USDT...
# 2025-09-22 01:58:25,174 - INFO - Fetched 365 candles for AAVE/USDT
# 2025-09-22 01:58:25,176 - INFO - Screening RONIN/USDT...
# 2025-09-22 01:58:25,211 - INFO - Screening S/USDT...
# 2025-09-22 01:58:25,252 - INFO - Screening KMNO/USDT...
# 2025-09-22 01:58:25,288 - INFO - Fetched 365 candles for ETC/USDT
# 2025-09-22 01:58:25,290 - INFO - Screening GALA/USDT...
# 2025-09-22 01:58:25,290 - INFO - Progress: 70/419 pairs processed
# 2025-09-22 01:58:25,294 - INFO - Screening LDO/USDT...
# 2025-09-22 01:58:25,328 - INFO - Screening FIL/USDT...
# 2025-09-22 01:58:25,364 - INFO - Screening TAO/USDT...
# 2025-09-22 01:58:25,386 - INFO - Loading LDO/USDT from cache
# 2025-09-22 01:58:25,389 - INFO - Screening TON/USDT...
# 2025-09-22 01:58:25,503 - INFO - Fetched 365 candles for FIL/USDT
# 2025-09-22 01:58:25,505 - INFO - Screening MEME/USDT...
# 2025-09-22 01:58:25,529 - INFO - Fetched 365 candles for TAO/USDT
# 2025-09-22 01:58:25,530 - INFO - Screening TREE/USDT...
# 2025-09-22 01:58:25,571 - INFO - Fetched 365 candles for TON/USDT
# 2025-09-22 01:58:25,573 - INFO - Screening MUBARAK/USDT...
# 2025-09-22 01:58:25,580 - INFO - Screening FLOKI/USDT...
# 2025-09-22 01:58:25,622 - INFO - Screening TIA/USDT...
# 2025-09-22 01:58:25,661 - INFO - Screening BCH/USDT...
# 2025-09-22 01:58:25,661 - INFO - Progress: 80/419 pairs processed
# 2025-09-22 01:58:25,666 - INFO - Screening REZ/USDT...
# 2025-09-22 01:58:25,709 - INFO - Loading TIA/USDT from cache
# 2025-09-22 01:58:25,713 - INFO - ✅ TIA/USDT passed all filters: Price=$1.6330, Hurst=0.4909, 7d Volume=$82,836,717
# 2025-09-22 01:58:25,714 - INFO - Screening AUCTION/USDT...
# 2025-09-22 01:58:25,714 - INFO - Progress: 82/419 - Found 1 valid pairs
# 2025-09-22 01:58:25,756 - INFO - Screening QI/USDT...
# 2025-09-22 01:58:25,830 - INFO - Fetched 365 candles for BCH/USDT
# 2025-09-22 01:58:25,832 - INFO - Screening RAY/USDT...
# 2025-09-22 01:58:25,834 - INFO - Screening ICP/USDT...
# 2025-09-22 01:58:25,883 - INFO - Fetched 365 candles for AUCTION/USDT
# 2025-09-22 01:58:25,885 - INFO - Screening FET/USDT...
# 2025-09-22 01:58:25,960 - INFO - Screening PLUME/USDT...
# 2025-09-22 01:58:26,008 - INFO - Fetched 365 candles for RAY/USDT
# 2025-09-22 01:58:26,010 - INFO - Screening USDE/USDT...
# 2025-09-22 01:58:26,023 - INFO - Fetched 365 candles for ICP/USDT
# 2025-09-22 01:58:26,025 - INFO - Screening USD1/USDT...
# 2025-09-22 01:58:26,038 - INFO - Screening PNUT/USDT...
# 2025-09-22 01:58:26,038 - INFO - Progress: 90/419 pairs processed
# 2025-09-22 01:58:26,105 - INFO - Screening KERNEL/USDT...
# 2025-09-22 01:58:26,125 - INFO - Screening POL/USDT...
# 2025-09-22 01:58:26,180 - INFO - Screening SKY/USDT...
# 2025-09-22 01:58:26,186 - INFO - Screening PYTH/USDT...
# 2025-09-22 01:58:26,201 - INFO - Screening AI/USDT...
# 2025-09-22 01:58:26,255 - INFO - Screening CYBER/USDT...
# 2025-09-22 01:58:26,288 - INFO - Screening RENDER/USDT...
# 2025-09-22 01:58:26,329 - INFO - Loading CYBER/USDT from cache
# 2025-09-22 01:58:26,461 - INFO - Fetched 365 candles for RENDER/USDT
# 2025-09-22 01:58:26,463 - INFO - Progress: 100/419 pairs processed
# 2025-09-22 01:58:26,464 - INFO - Processing batch 3: 50 pairs
# 2025-09-22 01:58:26,464 - INFO - Screening VIRTUAL/USDT...
# 2025-09-22 01:58:26,465 - INFO - Screening NEIRO/USDT...
# 2025-09-22 01:58:26,465 - INFO - Screening ID/USDT...
# 2025-09-22 01:58:26,562 - INFO - Screening MAV/USDT...
# 2025-09-22 01:58:26,563 - INFO - Screening AVA/USDT...
# 2025-09-22 01:58:26,626 - INFO - Fetched 165 candles for VIRTUAL/USDT
# 2025-09-22 01:58:26,628 - INFO - Screening ATOM/USDT...
# 2025-09-22 01:58:26,639 - INFO - Screening SHELL/USDT...
# 2025-09-22 01:58:26,661 - INFO - Screening CFX/USDT...
# 2025-09-22 01:58:26,722 - INFO - Screening BROCCOLI714/USDT...
# 2025-09-22 01:58:26,741 - INFO - Screening PENDLE/USDT...
# 2025-09-22 01:58:26,798 - INFO - Screening ARKM/USDT...
# 2025-09-22 01:58:26,819 - INFO - Loading PENDLE/USDT from cache
# 2025-09-22 01:58:26,822 - INFO - Screening C/USDT...
# 2025-09-22 01:58:26,840 - INFO - Fetched 365 candles for ATOM/USDT
# 2025-09-22 01:58:26,841 - INFO - Screening BABY/USDT...
# 2025-09-22 01:58:26,841 - INFO - Progress: 110/419 pairs processed
# 2025-09-22 01:58:26,877 - INFO - Screening SYRUP/USDT...
# 2025-09-22 01:58:26,897 - INFO - Screening WCT/USDT...
# 2025-09-22 01:58:26,923 - INFO - Screening GMX/USDT...
# 2025-09-22 01:58:26,967 - INFO - Screening COOKIE/USDT...
# 2025-09-22 01:58:26,970 - INFO - Screening USUAL/USDT...
# 2025-09-22 01:58:26,999 - INFO - Loading GMX/USDT from cache
# 2025-09-22 01:58:27,003 - INFO - Screening JUP/USDT...
# 2025-09-22 01:58:27,047 - INFO - Screening MOVE/USDT...
# 2025-09-22 01:58:27,063 - INFO - Screening YGG/USDT...
# 2025-09-22 01:58:27,082 - INFO - Screening HUMA/USDT...
# 2025-09-22 01:58:27,122 - INFO - Screening BFUSD/USDT...
# 2025-09-22 01:58:27,122 - INFO - Progress: 120/419 pairs processed
# 2025-09-22 01:58:27,141 - INFO - Screening 1000CAT/USDT...
# 2025-09-22 01:58:27,167 - INFO - Screening ALGO/USDT...
# 2025-09-22 01:58:27,204 - INFO - Screening PROVE/USDT...
# 2025-09-22 01:58:27,220 - INFO - Screening SPK/USDT...
# 2025-09-22 01:58:27,243 - INFO - Screening WOO/USDT...
# 2025-09-22 01:58:27,286 - INFO - Screening RESOLV/USDT...
# 2025-09-22 01:58:27,296 - INFO - Screening OM/USDT...
# 2025-09-22 01:58:27,320 - INFO - Screening C98/USDT...
# 2025-09-22 01:58:27,370 - INFO - Screening BMT/USDT...
# 2025-09-22 01:58:27,381 - INFO - Screening INJ/USDT...
# 2025-09-22 01:58:27,381 - INFO - Progress: 130/419 pairs processed
# 2025-09-22 01:58:27,400 - INFO - Screening OG/USDT...
# 2025-09-22 01:58:27,496 - INFO - Screening KAIA/USDT...
# 2025-09-22 01:58:27,554 - INFO - Fetched 365 candles for INJ/USDT
# 2025-09-22 01:58:27,555 - INFO - Screening ORDI/USDT...
# 2025-09-22 01:58:27,575 - INFO - Fetched 365 candles for OG/USDT
# 2025-09-22 01:58:27,577 - INFO - Screening XUSD/USDT...
# 2025-09-22 01:58:27,620 - INFO - Screening ENS/USDT...
# 2025-09-22 01:58:27,630 - INFO - Loading ORDI/USDT from cache
# 2025-09-22 01:58:27,633 - INFO - Screening RUNE/USDT...
# 2025-09-22 01:58:27,651 - INFO - Screening SFP/USDT...
# 2025-09-22 01:58:27,735 - INFO - Screening EUR/USDT...
# 2025-09-22 01:58:27,831 - INFO - Fetched 365 candles for RUNE/USDT
# 2025-09-22 01:58:27,831 - INFO - Fetched 365 candles for ENS/USDT
# 2025-09-22 01:58:27,833 - INFO - Screening VET/USDT...
# 2025-09-22 01:58:27,835 - INFO - Screening ASTR/USDT...
# 2025-09-22 01:58:27,835 - INFO - Progress: 140/419 pairs processed
# 2025-09-22 01:58:27,918 - INFO - Screening PAXG/USDT...
# 2025-09-22 01:58:27,920 - INFO - Fetched 365 candles for EUR/USDT
# 2025-09-22 01:58:27,924 - INFO - Screening AR/USDT...
# 2025-09-22 01:58:27,935 - INFO - Screening OMNI/USDT...
# 2025-09-22 01:58:28,087 - INFO - Fetched 365 candles for PAXG/USDT
# 2025-09-22 01:58:28,089 - INFO - ✅ PAXG/USDT passed all filters: Price=$3693.0200, Hurst=0.4999, 7d Volume=$94,947,901
# 2025-09-22 01:58:28,090 - INFO - Screening IMX/USDT...
# 2025-09-22 01:58:28,090 - INFO - Progress: 144/419 - Found 2 valid pairs
# 2025-09-22 01:58:28,105 - INFO - Fetched 365 candles for AR/USDT
# 2025-09-22 01:58:28,107 - INFO - Screening 1000SATS/USDT...
# 2025-09-22 01:58:28,129 - INFO - Fetched 365 candles for OMNI/USDT
# 2025-09-22 01:58:28,130 - INFO - Screening APE/USDT...
# 2025-09-22 01:58:28,167 - INFO - Screening NMR/USDT...
# 2025-09-22 01:58:28,341 - INFO - Fetched 365 candles for NMR/USDT
# 2025-09-22 01:58:28,344 - INFO - Progress: 150/419 pairs processed
# 2025-09-22 01:58:28,345 - INFO - Processing batch 4: 50 pairs
# 2025-09-22 01:58:28,346 - INFO - Screening IO/USDT...
# 2025-09-22 01:58:28,347 - INFO - Screening AWE/USDT...
# 2025-09-22 01:58:28,348 - INFO - Screening ZRO/USDT...
# 2025-09-22 01:58:28,424 - INFO - Screening STRK/USDT...
# 2025-09-22 01:58:28,444 - INFO - Screening DODO/USDT...
# 2025-09-22 01:58:28,499 - INFO - Screening XVS/USDT...
# 2025-09-22 01:58:28,519 - INFO - Screening SUSHI/USDT...
# 2025-09-22 01:58:28,554 - INFO - Fetched 365 candles for ZRO/USDT
# 2025-09-22 01:58:28,558 - INFO - Screening SAGA/USDT...
# 2025-09-22 01:58:28,594 - INFO - Screening BOME/USDT...
# 2025-09-22 01:58:28,635 - INFO - Screening CGPT/USDT...
# 2025-09-22 01:58:28,670 - INFO - Fetched 365 candles for XVS/USDT
# 2025-09-22 01:58:28,672 - INFO - Screening AIXBT/USDT...
# 2025-09-22 01:58:28,685 - INFO - Screening PARTI/USDT...
# 2025-09-22 01:58:28,712 - INFO - Screening SIGN/USDT...
# 2025-09-22 01:58:28,712 - INFO - Progress: 160/419 pairs processed
# 2025-09-22 01:58:28,750 - INFO - Screening WBTC/USDT...
# 2025-09-22 01:58:28,765 - INFO - Screening RED/USDT...
# 2025-09-22 01:58:28,788 - INFO - Screening 1MBABYDOGE/USDT...
# 2025-09-22 01:58:28,827 - INFO - Loading WBTC/USDT from cache
# 2025-09-22 01:58:28,831 - INFO - Screening TOWNS/USDT...
# 2025-09-22 01:58:28,847 - INFO - Screening FTT/USDT...
# 2025-09-22 01:58:28,865 - INFO - Screening TRB/USDT...
# 2025-09-22 01:58:28,907 - INFO - Screening NEO/USDT...
# 2025-09-22 01:58:28,927 - INFO - Screening INIT/USDT...
# 2025-09-22 01:58:29,004 - INFO - Screening XAI/USDT...
# 2025-09-22 01:58:29,039 - INFO - Fetched 365 candles for TRB/USDT
# 2025-09-22 01:58:29,041 - INFO - Screening ROSE/USDT...
# 2025-09-22 01:58:29,041 - INFO - Progress: 170/419 pairs processed
# 2025-09-22 01:58:29,073 - INFO - Fetched 365 candles for NEO/USDT
# 2025-09-22 01:58:29,074 - INFO - Screening AGLD/USDT...
# 2025-09-22 01:58:29,081 - INFO - Screening SAND/USDT...
# 2025-09-22 01:58:29,117 - INFO - Screening GRT/USDT...
# 2025-09-22 01:58:29,151 - INFO - Screening ZK/USDT...
# 2025-09-22 01:58:29,171 - INFO - Screening JTO/USDT...
# 2025-09-22 01:58:29,198 - INFO - Screening TKO/USDT...
# 2025-09-22 01:58:29,228 - INFO - Screening AXS/USDT...
# 2025-09-22 01:58:29,246 - INFO - Loading JTO/USDT from cache
# 2025-09-22 01:58:29,249 - INFO - ✅ JTO/USDT passed all filters: Price=$1.8110, Hurst=0.4685, 7d Volume=$43,097,522
# 2025-09-22 01:58:29,250 - INFO - Screening BANANAS31/USDT...
# 2025-09-22 01:58:29,250 - INFO - Progress: 178/419 - Found 3 valid pairs
# 2025-09-22 01:58:29,272 - INFO - Screening BNSOL/USDT...
# 2025-09-22 01:58:29,325 - INFO - Screening KAITO/USDT...
# 2025-09-22 01:58:29,325 - INFO - Progress: 180/419 pairs processed
# 2025-09-22 01:58:29,393 - INFO - Fetched 365 candles for AXS/USDT
# 2025-09-22 01:58:29,395 - INFO - Screening A/USDT...
# 2025-09-22 01:58:29,457 - INFO - Fetched 341 candles for BNSOL/USDT
# 2025-09-22 01:58:29,459 - INFO - Screening HYPER/USDT...
# 2025-09-22 01:58:29,472 - INFO - Screening SSV/USDT...
# 2025-09-22 01:58:29,500 - INFO - Fetched 215 candles for KAITO/USDT
# 2025-09-22 01:58:29,504 - INFO - Screening ZEC/USDT...
# 2025-09-22 01:58:29,540 - INFO - Screening STO/USDT...
# 2025-09-22 01:58:29,555 - INFO - Loading SSV/USDT from cache
# 2025-09-22 01:58:29,558 - INFO - Screening PEOPLE/USDT...
# 2025-09-22 01:58:29,616 - INFO - Screening SAHARA/USDT...
# 2025-09-22 01:58:29,636 - INFO - Screening EPIC/USDT...
# 2025-09-22 01:58:29,691 - INFO - Fetched 365 candles for ZEC/USDT
# 2025-09-22 01:58:29,694 - INFO - Screening IOTX/USDT...
# 2025-09-22 01:58:29,695 - INFO - Screening ARPA/USDT...
# 2025-09-22 01:58:29,696 - INFO - Progress: 190/419 pairs processed
# 2025-09-22 01:58:29,773 - INFO - Screening RDNT/USDT...
# 2025-09-22 01:58:29,791 - INFO - Screening SKL/USDT...
# 2025-09-22 01:58:29,800 - INFO - Fetched 194 candles for EPIC/USDT
# 2025-09-22 01:58:29,802 - INFO - Screening LPT/USDT...
# 2025-09-22 01:58:29,847 - INFO - Screening TURBO/USDT...
# 2025-09-22 01:58:29,867 - INFO - Screening ACT/USDT...
# 2025-09-22 01:58:29,942 - INFO - Screening LQTY/USDT...
# 2025-09-22 01:58:29,944 - INFO - Screening HAEDAL/USDT...
# 2025-09-22 01:58:29,976 - INFO - Fetched 365 candles for LPT/USDT
# 2025-09-22 01:58:30,038 - INFO - Progress: 200/419 pairs processed
# 2025-09-22 01:58:30,039 - INFO - Processing batch 5: 50 pairs
# 2025-09-22 01:58:30,040 - INFO - Screening MAGIC/USDT...
# 2025-09-22 01:58:30,041 - INFO - Screening MANA/USDT...
# 2025-09-22 01:58:30,042 - INFO - Screening PROM/USDT...
# 2025-09-22 01:58:30,114 - INFO - Screening BEAMX/USDT...
# 2025-09-22 01:58:30,140 - INFO - Loading PROM/USDT from cache
# 2025-09-22 01:58:30,144 - INFO - Screening RSR/USDT...
# 2025-09-22 01:58:30,146 - INFO - Screening KAVA/USDT...
# 2025-09-22 01:58:30,188 - INFO - Screening THETA/USDT...
# 2025-09-22 01:58:30,219 - INFO - Screening BEL/USDT...
# 2025-09-22 01:58:30,240 - INFO - Screening GMT/USDT...
# 2025-09-22 01:58:30,265 - INFO - Screening PIXEL/USDT...
# 2025-09-22 01:58:30,294 - INFO - Screening QNT/USDT...
# 2025-09-22 01:58:30,325 - INFO - Screening ALPINE/USDT...
# 2025-09-22 01:58:30,341 - INFO - Screening CTK/USDT...
# 2025-09-22 01:58:30,341 - INFO - Progress: 210/419 pairs processed
# 2025-09-22 01:58:30,403 - INFO - Loading ALPINE/USDT from cache
# 2025-09-22 01:58:30,407 - INFO - Screening CVX/USDT...
# 2025-09-22 01:58:30,422 - INFO - Screening STX/USDT...
# 2025-09-22 01:58:30,475 - INFO - Fetched 365 candles for QNT/USDT
# 2025-09-22 01:58:30,477 - INFO - Screening CETUS/USDT...
# 2025-09-22 01:58:30,505 - INFO - Screening ALT/USDT...
# 2025-09-22 01:58:30,553 - INFO - Screening JASMY/USDT...
# 2025-09-22 01:58:30,592 - INFO - Screening COW/USDT...
# 2025-09-22 01:58:30,604 - INFO - Fetched 365 candles for CVX/USDT
# 2025-09-22 01:58:30,607 - INFO - Screening MANTA/USDT...
# 2025-09-22 01:58:30,634 - INFO - Screening HFT/USDT...
# 2025-09-22 01:58:30,670 - INFO - Screening ACH/USDT...
# 2025-09-22 01:58:30,690 - INFO - Screening NXPC/USDT...
# 2025-09-22 01:58:30,690 - INFO - Progress: 220/419 pairs processed
# 2025-09-22 01:58:30,709 - INFO - Screening D/USDT...
# 2025-09-22 01:58:30,747 - INFO - Screening DYM/USDT...
# 2025-09-22 01:58:30,765 - INFO - Screening API3/USDT...
# 2025-09-22 01:58:30,785 - INFO - Screening JST/USDT...
# 2025-09-22 01:58:30,822 - INFO - Screening DOGS/USDT...
# 2025-09-22 01:58:30,843 - INFO - Screening PORTAL/USDT...
# 2025-09-22 01:58:30,867 - INFO - Screening IOTA/USDT...
# 2025-09-22 01:58:30,898 - INFO - Screening MINA/USDT...
# 2025-09-22 01:58:30,918 - INFO - Screening EGLD/USDT...
# 2025-09-22 01:58:30,946 - INFO - Screening NOT/USDT...
# 2025-09-22 01:58:30,946 - INFO - Progress: 230/419 pairs processed
# 2025-09-22 01:58:30,973 - INFO - Screening PHA/USDT...
# 2025-09-22 01:58:31,021 - INFO - Screening KSM/USDT...
# 2025-09-22 01:58:31,048 - INFO - Screening COMP/USDT...
# 2025-09-22 01:58:31,085 - INFO - Fetched 365 candles for EGLD/USDT
# 2025-09-22 01:58:31,087 - INFO - Screening SOLV/USDT...
# 2025-09-22 01:58:31,163 - INFO - Screening ANIME/USDT...
# 2025-09-22 01:58:31,217 - INFO - Fetched 365 candles for COMP/USDT
# 2025-09-22 01:58:31,219 - INFO - Screening GPS/USDT...
# 2025-09-22 01:58:31,237 - INFO - Screening SNX/USDT...
# 2025-09-22 01:58:31,314 - INFO - Screening 1000CHEEMS/USDT...
# 2025-09-22 01:58:31,353 - INFO - Fetched 365 candles for KSM/USDT
# 2025-09-22 01:58:31,355 - INFO - Screening GTC/USDT...
# 2025-09-22 01:58:31,391 - INFO - Screening METIS/USDT...
# 2025-09-22 01:58:31,391 - INFO - Progress: 240/419 pairs processed
# 2025-09-22 01:58:31,432 - INFO - Screening PYR/USDT...
# 2025-09-22 01:58:31,560 - INFO - Fetched 365 candles for METIS/USDT
# 2025-09-22 01:58:31,563 - INFO - Screening BIGTIME/USDT...
# 2025-09-22 01:58:31,567 - INFO - Screening MBOX/USDT...
# 2025-09-22 01:58:31,637 - INFO - Screening MBL/USDT...
# 2025-09-22 01:58:31,692 - INFO - Fetched 365 candles for PYR/USDT
# 2025-09-22 01:58:31,693 - INFO - Screening CKB/USDT...
# 2025-09-22 01:58:31,712 - INFO - Screening WIN/USDT...
# 2025-09-22 01:58:31,769 - INFO - Screening NEWT/USDT...
# 2025-09-22 01:58:31,846 - INFO - Progress: 250/419 pairs processed
# 2025-09-22 01:58:31,847 - INFO - Processing batch 6: 50 pairs
# 2025-09-22 01:58:31,848 - INFO - Screening JOE/USDT...
# 2025-09-22 01:58:31,848 - INFO - Screening HMSTR/USDT...
# 2025-09-22 01:58:31,848 - INFO - Screening FIDA/USDT...
# 2025-09-22 01:58:31,955 - INFO - Screening BLUR/USDT...
# 2025-09-22 01:58:31,957 - INFO - Screening ASR/USDT...
# 2025-09-22 01:58:32,030 - INFO - Screening LAYER/USDT...
# 2025-09-22 01:58:32,065 - INFO - Screening SXT/USDT...
# 2025-09-22 01:58:32,158 - INFO - Screening LUNC/USDT...
# 2025-09-22 01:58:32,234 - INFO - Screening SANTOS/USDT...
# 2025-09-22 01:58:32,244 - INFO - Screening ACE/USDT...
# 2025-09-22 01:58:32,327 - INFO - Screening SPELL/USDT...
# 2025-09-22 01:58:32,391 - INFO - Fetched 365 candles for ASR/USDT
# 2025-09-22 01:58:32,394 - INFO - Screening RARE/USDT...
# 2025-09-22 01:58:32,401 - INFO - Fetched 365 candles for SANTOS/USDT
# 2025-09-22 01:58:32,402 - INFO - Screening HOME/USDT...
# 2025-09-22 01:58:32,402 - INFO - Progress: 260/419 pairs processed
# 2025-09-22 01:58:32,478 - INFO - Screening WBETH/USDT...
# 2025-09-22 01:58:32,491 - INFO - Screening CHZ/USDT...
# 2025-09-22 01:58:32,542 - INFO - Screening CTSI/USDT...
# 2025-09-22 01:58:32,576 - INFO - Screening ZEN/USDT...
# 2025-09-22 01:58:32,755 - INFO - Screening LUNA/USDT...
# 2025-09-22 01:58:32,805 - INFO - Fetched 365 candles for WBETH/USDT
# 2025-09-22 01:58:32,807 - INFO - Screening SYN/USDT...
# 2025-09-22 01:58:32,818 - INFO - Fetched 365 candles for ZEN/USDT
# 2025-09-22 01:58:32,820 - INFO - Screening BANANA/USDT...
# 2025-09-22 01:58:32,829 - INFO - Screening ILV/USDT...
# 2025-09-22 01:58:32,885 - INFO - Screening SUPER/USDT...
# 2025-09-22 01:58:32,959 - INFO - Screening KDA/USDT...
# 2025-09-22 01:58:32,959 - INFO - Progress: 270/419 pairs processed
# 2025-09-22 01:58:33,035 - INFO - Screening FXS/USDT...
# 2025-09-22 01:58:33,145 - INFO - Fetched 365 candles for BANANA/USDT
# 2025-09-22 01:58:33,147 - INFO - Screening HEI/USDT...
# 2025-09-22 01:58:33,200 - INFO - Fetched 365 candles for FXS/USDT
# 2025-09-22 01:58:33,201 - INFO - Screening ZRX/USDT...
# 2025-09-22 01:58:33,224 - INFO - Screening ORCA/USDT...
# 2025-09-22 01:58:33,230 - INFO - Fetched 365 candles for ILV/USDT
# 2025-09-22 01:58:33,231 - INFO - Screening RPL/USDT...
# 2025-09-22 01:58:33,279 - INFO - Screening FUN/USDT...
# 2025-09-22 01:58:33,353 - INFO - Screening PHB/USDT...
# 2025-09-22 01:58:33,423 - INFO - Fetched 365 candles for RPL/USDT
# 2025-09-22 01:58:33,425 - INFO - Screening RVN/USDT...
# 2025-09-22 01:58:33,428 - INFO - Screening FIS/USDT...
# 2025-09-22 01:58:33,463 - INFO - Fetched 291 candles for ORCA/USDT
# 2025-09-22 01:58:33,464 - INFO - Screening COTI/USDT...
# 2025-09-22 01:58:33,465 - INFO - Progress: 280/419 pairs processed
# 2025-09-22 01:58:33,502 - INFO - Screening ERA/USDT...
# 2025-09-22 01:58:33,520 - INFO - Screening AXL/USDT...
# 2025-09-22 01:58:33,544 - INFO - Screening NIL/USDT...
# 2025-09-22 01:58:33,585 - INFO - Screening GUN/USDT...
# 2025-09-22 01:58:33,595 - INFO - Screening ONG/USDT...
# 2025-09-22 01:58:33,618 - INFO - Screening SOPH/USDT...
# 2025-09-22 01:58:33,663 - INFO - Screening VANRY/USDT...
# 2025-09-22 01:58:33,681 - INFO - Screening MOVR/USDT...
# 2025-09-22 01:58:33,699 - INFO - Screening LUMIA/USDT...
# 2025-09-22 01:58:33,781 - INFO - Screening USTC/USDT...
# 2025-09-22 01:58:33,781 - INFO - Progress: 290/419 pairs processed
# 2025-09-22 01:58:33,800 - INFO - Screening POND/USDT...
# 2025-09-22 01:58:33,863 - INFO - Screening BICO/USDT...
# 2025-09-22 01:58:33,877 - INFO - Fetched 365 candles for MOVR/USDT
# 2025-09-22 01:58:33,879 - INFO - Screening CHESS/USDT...
# 2025-09-22 01:58:33,947 - INFO - Screening CATI/USDT...
# 2025-09-22 01:58:33,971 - INFO - Screening ENJ/USDT...
# 2025-09-22 01:58:34,021 - INFO - Screening 1INCH/USDT...
# 2025-09-22 01:58:34,050 - INFO - Screening XTZ/USDT...
# 2025-09-22 01:58:34,124 - INFO - Progress: 300/419 pairs processed
# 2025-09-22 01:58:34,125 - INFO - Processing batch 7: 50 pairs
# 2025-09-22 01:58:34,126 - INFO - Screening BAND/USDT...
# 2025-09-22 01:58:34,126 - INFO - Screening MASK/USDT...
# 2025-09-22 01:58:34,126 - INFO - Screening STG/USDT...
# 2025-09-22 01:58:34,202 - INFO - Screening NFP/USDT...
# 2025-09-22 01:58:34,219 - INFO - Screening ATM/USDT...
# 2025-09-22 01:58:34,279 - INFO - Screening JUV/USDT...
# 2025-09-22 01:58:34,327 - INFO - Fetched 365 candles for MASK/USDT
# 2025-09-22 01:58:34,328 - INFO - Screening CHR/USDT...
# 2025-09-22 01:58:34,407 - INFO - Screening ONE/USDT...
# 2025-09-22 01:58:34,454 - INFO - Fetched 365 candles for ATM/USDT
# 2025-09-22 01:58:34,457 - INFO - Screening T/USDT...
# 2025-09-22 01:58:34,505 - INFO - Screening ALICE/USDT...
# 2025-09-22 01:58:34,513 - INFO - Fetched 365 candles for JUV/USDT
# 2025-09-22 01:58:34,514 - INFO - Screening ACX/USDT...
# 2025-09-22 01:58:34,531 - INFO - Screening QKC/USDT...
# 2025-09-22 01:58:34,584 - INFO - Screening DASH/USDT...
# 2025-09-22 01:58:34,584 - INFO - Progress: 310/419 pairs processed
# 2025-09-22 01:58:34,605 - INFO - Screening YFI/USDT...
# 2025-09-22 01:58:34,623 - INFO - Screening UMA/USDT...
# 2025-09-22 01:58:34,751 - INFO - Fetched 365 candles for DASH/USDT
# 2025-09-22 01:58:34,752 - INFO - Screening FLUX/USDT...
# 2025-09-22 01:58:34,771 - INFO - Fetched 365 candles for YFI/USDT
# 2025-09-22 01:58:34,771 - INFO - Screening TRU/USDT...
# 2025-09-22 01:58:34,827 - INFO - Screening QTUM/USDT...
# 2025-09-22 01:58:34,852 - INFO - Screening ZIL/USDT...
# 2025-09-22 01:58:34,862 - INFO - Fetched 365 candles for UMA/USDT
# 2025-09-22 01:58:34,863 - INFO - Screening SXP/USDT...
# 2025-09-22 01:58:34,929 - INFO - Screening OGN/USDT...
# 2025-09-22 01:58:34,999 - INFO - Fetched 365 candles for QTUM/USDT
# 2025-09-22 01:58:35,000 - INFO - Screening VOXEL/USDT...
# 2025-09-22 01:58:35,004 - INFO - Screening CITY/USDT...
# 2025-09-22 01:58:35,004 - INFO - Progress: 320/419 pairs processed
# 2025-09-22 01:58:35,075 - INFO - Screening TLM/USDT...
# 2025-09-22 01:58:35,091 - INFO - Screening HOT/USDT...
# 2025-09-22 01:58:35,149 - INFO - Screening TNSR/USDT...
# 2025-09-22 01:58:35,168 - INFO - Screening NTRN/USDT...
# 2025-09-22 01:58:35,230 - INFO - Screening UTK/USDT...
# 2025-09-22 01:58:35,243 - INFO - Screening POLYX/USDT...
# 2025-09-22 01:58:35,307 - INFO - Screening CELR/USDT...
# 2025-09-22 01:58:35,326 - INFO - Screening GLMR/USDT...
# 2025-09-22 01:58:35,356 - INFO - Screening SCR/USDT...
# 2025-09-22 01:58:35,382 - INFO - Screening HIGH/USDT...
# 2025-09-22 01:58:35,382 - INFO - Progress: 330/419 pairs processed
# 2025-09-22 01:58:35,402 - INFO - Screening RLC/USDT...
# 2025-09-22 01:58:35,431 - INFO - Screening G/USDT...
# 2025-09-22 01:58:35,457 - INFO - Screening DIA/USDT...
# 2025-09-22 01:58:35,506 - INFO - Screening OXT/USDT...
# 2025-09-22 01:58:35,532 - INFO - Screening ANKR/USDT...
# 2025-09-22 01:58:35,567 - INFO - Fetched 365 candles for RLC/USDT
# 2025-09-22 01:58:35,568 - INFO - Screening VELODROME/USDT...
# 2025-09-22 01:58:35,581 - INFO - Screening FLOW/USDT...
# 2025-09-22 01:58:35,609 - INFO - Screening XEC/USDT...
# 2025-09-22 01:58:35,645 - INFO - Screening QUICK/USDT...
# 2025-09-22 01:58:35,662 - INFO - Screening CELO/USDT...
# 2025-09-22 01:58:35,662 - INFO - Progress: 340/419 pairs processed
# 2025-09-22 01:58:35,685 - INFO - Screening NEXO/USDT...
# 2025-09-22 01:58:35,722 - INFO - Screening FLM/USDT...
# 2025-09-22 01:58:35,742 - INFO - Screening IDEX/USDT...
# 2025-09-22 01:58:35,796 - INFO - Screening DEGO/USDT...
# 2025-09-22 01:58:35,817 - INFO - Screening ACA/USDT...
# 2025-09-22 01:58:35,873 - INFO - Screening BAR/USDT...
# 2025-09-22 01:58:35,892 - INFO - Screening SLP/USDT...
# 2025-09-22 01:58:36,012 - INFO - Fetched 365 candles for NEXO/USDT
# 2025-09-22 01:58:36,013 - INFO - Progress: 350/419 pairs processed
# 2025-09-22 01:58:36,015 - INFO - Processing batch 8: 50 pairs
# 2025-09-22 01:58:36,015 - INFO - Screening XVG/USDT...
# 2025-09-22 01:58:36,015 - INFO - Screening LRC/USDT...
# 2025-09-22 01:58:36,016 - INFO - Screening ARK/USDT...
# 2025-09-22 01:58:36,092 - INFO - Screening VTHO/USDT...
# 2025-09-22 01:58:36,111 - INFO - Screening IOST/USDT...
# 2025-09-22 01:58:36,123 - INFO - Screening ONT/USDT...
# 2025-09-22 01:58:36,168 - INFO - Screening A2Z/USDT...
# 2025-09-22 01:58:36,189 - INFO - Screening MDT/USDT...
# 2025-09-22 01:58:36,208 - INFO - Screening VIC/USDT...
# 2025-09-22 01:58:36,245 - INFO - Screening GAS/USDT...
# 2025-09-22 01:58:36,266 - INFO - Screening TUSD/USDT...
# 2025-09-22 01:58:36,284 - INFO - Screening DGB/USDT...
# 2025-09-22 01:58:36,319 - INFO - Screening COS/USDT...
# 2025-09-22 01:58:36,320 - INFO - Progress: 360/419 pairs processed
# 2025-09-22 01:58:36,340 - INFO - Screening DF/USDT...
# 2025-09-22 01:58:36,361 - INFO - Screening ADX/USDT...
# 2025-09-22 01:58:36,397 - INFO - Screening OSMO/USDT...
# 2025-09-22 01:58:36,416 - INFO - Screening KNC/USDT...
# 2025-09-22 01:58:36,436 - INFO - Screening GNS/USDT...
# 2025-09-22 01:58:36,473 - INFO - Screening SCRT/USDT...
# 2025-09-22 01:58:36,490 - INFO - Screening TFUEL/USDT...
# 2025-09-22 01:58:36,509 - INFO - Screening DUSK/USDT...
# 2025-09-22 01:58:36,548 - INFO - Screening SYS/USDT...
# 2025-09-22 01:58:36,569 - INFO - Screening AMP/USDT...
# 2025-09-22 01:58:36,570 - INFO - Progress: 370/419 pairs processed
# 2025-09-22 01:58:36,587 - INFO - Screening ATA/USDT...
# 2025-09-22 01:58:36,623 - INFO - Screening GLM/USDT...
# 2025-09-22 01:58:36,646 - INFO - Screening RAD/USDT...
# 2025-09-22 01:58:36,664 - INFO - Screening STORJ/USDT...
# 2025-09-22 01:58:36,697 - INFO - Screening SC/USDT...
# 2025-09-22 01:58:36,721 - INFO - Screening MLN/USDT...
# 2025-09-22 01:58:36,741 - INFO - Screening BAT/USDT...
# 2025-09-22 01:58:36,772 - INFO - Screening AUDIO/USDT...
# 2025-09-22 01:58:36,795 - INFO - Screening ALCX/USDT...
# 2025-09-22 01:58:36,817 - INFO - Screening BTTC/USDT...
# 2025-09-22 01:58:36,817 - INFO - Progress: 380/419 pairs processed
# 2025-09-22 01:58:36,848 - INFO - Screening STEEM/USDT...
# 2025-09-22 01:58:36,872 - INFO - Screening PSG/USDT...
# 2025-09-22 01:58:36,891 - INFO - Screening HIVE/USDT...
# 2025-09-22 01:58:36,925 - INFO - Screening LAZIO/USDT...
# 2025-09-22 01:58:36,948 - INFO - Screening ICX/USDT...
# 2025-09-22 01:58:36,965 - INFO - Screening FARM/USDT...
# 2025-09-22 01:58:37,000 - INFO - Screening NKN/USDT...
# 2025-09-22 01:58:37,024 - INFO - Screening EURI/USDT...
# 2025-09-22 01:58:37,041 - INFO - Screening MTL/USDT...
# 2025-09-22 01:58:37,078 - INFO - Screening FIO/USDT...
# 2025-09-22 01:58:37,078 - INFO - Progress: 390/419 pairs processed
# 2025-09-22 01:58:37,098 - INFO - Screening RIF/USDT...
# 2025-09-22 01:58:37,120 - INFO - Screening REI/USDT...
# 2025-09-22 01:58:37,153 - INFO - Screening DATA/USDT...
# 2025-09-22 01:58:37,171 - INFO - Screening IQ/USDT...
# 2025-09-22 01:58:37,195 - INFO - Screening LSK/USDT...
# 2025-09-22 01:58:37,231 - INFO - Screening ACM/USDT...
# 2025-09-22 01:58:37,249 - INFO - Screening WAXP/USDT...
# 2025-09-22 01:58:37,327 - INFO - Progress: 400/419 pairs processed
# 2025-09-22 01:58:37,328 - INFO - Processing batch 9: 19 pairs
# 2025-09-22 01:58:37,329 - INFO - Screening DENT/USDT...
# 2025-09-22 01:58:37,329 - INFO - Screening PUNDIX/USDT...
# 2025-09-22 01:58:37,330 - INFO - Screening FORTH/USDT...
# 2025-09-22 01:58:37,404 - INFO - Screening STRAX/USDT...
# 2025-09-22 01:58:37,424 - INFO - Screening PIVX/USDT...
# 2025-09-22 01:58:37,425 - INFO - Screening BIFI/USDT...
# 2025-09-22 01:58:37,478 - INFO - Screening GHST/USDT...
# 2025-09-22 01:58:37,499 - INFO - Screening XNO/USDT...
# 2025-09-22 01:58:37,519 - INFO - Screening GNO/USDT...
# 2025-09-22 01:58:37,553 - INFO - Screening PORTO/USDT...
# 2025-09-22 01:58:37,575 - INFO - Screening USDP/USDT...
# 2025-09-22 01:58:37,595 - INFO - Screening CVC/USDT...
# 2025-09-22 01:58:37,627 - INFO - Screening DCR/USDT...
# 2025-09-22 01:58:37,627 - INFO - Progress: 410/419 pairs processed
# 2025-09-22 01:58:37,654 - INFO - Screening POWR/USDT...
# 2025-09-22 01:58:37,676 - INFO - Screening ARDR/USDT...
# 2025-09-22 01:58:37,701 - INFO - Screening WAN/USDT...
# 2025-09-22 01:58:37,729 - INFO - Screening BNT/USDT...
# 2025-09-22 01:58:37,753 - INFO - Screening REQ/USDT...
# 2025-09-22 01:58:37,777 - INFO - Screening AEUR/USDT...
# 2025-09-22 01:58:37,853 - INFO - Screening completed. 3 pairs passed filters.
# 2025-09-22 01:58:37,854 - INFO - Top 3 pairs selected.
# 2025-09-22 01:58:37,854 - INFO -
# ⏱️  Screening completed in 32.64 seconds
# 2025-09-22 01:58:37,855 - INFO - 📊 Found 3 pairs that passed all criteria
# 2025-09-22 01:58:37,855 - INFO -
# 🏆 TOP PAIRS FOR GRID TRADING:
# 2025-09-22 01:58:37,856 - INFO - ------------------------------------------------------------
# 2025-09-22 01:58:37,857 - INFO - 1. PAXG/USDT
# 2025-09-22 01:58:37,857 - INFO -    💰 Price: $3693.0200
# 2025-09-22 01:58:37,858 - INFO -    📈 Hurst: 0.4999
# 2025-09-22 01:58:37,860 - INFO -    💵 7d Volume: $94,947,901
# 2025-09-22 01:58:37,860 - INFO -    📊 7d Volume (base): 25,805.33
# 2025-09-22 01:58:37,860 - INFO -
# 2025-09-22 01:58:37,861 - INFO - 2. TIA/USDT
# 2025-09-22 01:58:37,862 - INFO -    💰 Price: $1.6330
# 2025-09-22 01:58:37,862 - INFO -    📈 Hurst: 0.4909
# 2025-09-22 01:58:37,863 - INFO -    💵 7d Volume: $82,836,717
# 2025-09-22 01:58:37,863 - INFO -    📊 7d Volume (base): 47,624,357.65
# 2025-09-22 01:58:37,864 - INFO -
# 2025-09-22 01:58:37,864 - INFO - 3. JTO/USDT
# 2025-09-22 01:58:37,865 - INFO -    💰 Price: $1.8110
# 2025-09-22 01:58:37,865 - INFO -    📈 Hurst: 0.4685
# 2025-09-22 01:58:37,866 - INFO -    💵 7d Volume: $43,097,522
# 2025-09-22 01:58:37,866 - INFO -    📊 7d Volume (base): 22,012,393.70
# 2025-09-22 01:58:37,867 - INFO -
# 2025-09-22 01:58:37,869 - INFO - Results saved to screening_results.json
# 2025-09-22 01:58:37,869 - INFO - 📋 SCREENING SUMMARY:
# 2025-09-22 01:58:37,870 - INFO -    Min Price: $1.0
# 2025-09-22 01:58:37,870 - INFO -    Min 7d Volume: $10,000,000
# 2025-09-22 01:58:37,871 - INFO -    Max Hurst: 0.5
# 2025-09-22 01:58:37,872 - INFO -    Data Period: 1 years
