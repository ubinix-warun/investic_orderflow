# %%
#!/usr/bin/env python3
"""
Market Screener for Grid Trading Pairs
Fetches all spot/USDT pairs from Binance and applies screening criteria
"""

import ccxt
import pandas as pd
import numpy as np
from typing import List, Dict, Optional, Tuple
from dataclasses import dataclass
from datetime import datetime, timedelta
import time
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
import json
import os
from pathlib import Path

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

@dataclass
class PairData:
    """Data structure for trading pair information"""
    symbol: str
    close_price: float
    hurst_exponent: float
    volume_7d: float
    volume_7d_usd: float
    last_update: datetime
    ohlcv_data: Optional[pd.DataFrame] = None

@dataclass
class ScreeningCriteria:
    """Screening criteria configuration with validation"""
    min_price: float = 1.0
    min_volume_7d_usd: float = 10_000_000
    max_hurst: float = 0.5  # Hurst < 0.5 for mean-reverting
    years_of_data: int = 1  # 1 year of data
    top_n_pairs: int = 5  # Top 5 pairs
    
    def __post_init__(self):
        """Validate criteria values"""
        if self.min_price <= 0:
            raise ValueError("min_price must be positive")
        if self.min_volume_7d_usd <= 0:
            raise ValueError("min_volume_7d_usd must be positive")
        if not 0 <= self.max_hurst <= 1:
            raise ValueError("max_hurst must be between 0 and 1")
        if self.years_of_data <= 0:
            raise ValueError("years_of_data must be positive")
        if self.top_n_pairs <= 0:
            raise ValueError("top_n_pairs must be positive")

class HurstCalculator:
    """Calculate Hurst exponent for time series analysis with robust error handling"""
    
    @staticmethod
    def calculate_hurst(price_series: pd.Series) -> float:
        """
        Calculate Hurst exponent using R/S analysis
        
        Args:
            price_series: Price series (typically close prices)
            
        Returns:
            Hurst exponent value (0-1, where <0.5 = mean-reverting, >0.5 = trending)
        """
        try:
            # Input validation
            if price_series is None or price_series.empty:
                logger.warning("Empty price series provided for Hurst calculation")
                return 0.5
            
            if len(price_series) < 20:  # Need at least 20 data points
                logger.warning(f"Insufficient data for Hurst calculation: {len(price_series)} points")
                return 0.5
            
            # Remove any NaN or infinite values
            clean_series = price_series.dropna()
            if len(clean_series) < 20:
                logger.warning("Insufficient clean data after removing NaN values")
                return 0.5
            
            # Calculate log returns
            log_returns = np.log(clean_series / clean_series.shift(1)).dropna()
            
            if len(log_returns) < 20:
                logger.warning("Insufficient log returns for Hurst calculation")
                return 0.5
            
            # Check for constant values (no variance)
            if log_returns.std() == 0:
                logger.warning("No variance in log returns, returning neutral Hurst")
                return 0.5
            
            # R/S analysis
            n = len(log_returns)
            mean_return = log_returns.mean()
            
            # Calculate cumulative deviations
            cumsum_deviations = (log_returns - mean_return).cumsum()
            
            # Calculate range R
            R = cumsum_deviations.max() - cumsum_deviations.min()
            
            # Calculate standard deviation S
            S = log_returns.std()
            
            if S == 0 or R == 0:
                logger.warning("Zero variance or range in R/S calculation")
                return 0.5
            
            # R/S ratio
            rs_ratio = R / S
            
            if rs_ratio <= 0:
                logger.warning("Invalid R/S ratio, returning neutral Hurst")
                return 0.5
            
            # Hurst exponent calculation
            hurst = np.log(rs_ratio) / np.log(n)
            
            # Clamp between 0 and 1
            hurst = max(0.0, min(1.0, hurst))
            
            return float(hurst)
            
        except Exception as e:
            logger.error(f"Error calculating Hurst exponent: {e}")
            return 0.5  # Return neutral value on error

class BinanceDataFetcher:
    """Enhanced data fetcher for Binance with error handling and caching"""
    
    def __init__(self, api_key: Optional[str] = None, api_secret: Optional[str] = None):
        # Configure exchange with API credentials if available
        exchange_config = {
            "enableRateLimit": True,
            "options": {"defaultType": "spot"}  # Make sure it's spot, not futures
        }
        
        # Add API credentials if provided
        if api_key and api_secret:
            exchange_config.update({
                "apiKey": api_key,
                "secret": api_secret
            })
            logger.info("🔑 Using API credentials for enhanced data access")
        else:
            logger.info("🌐 Using public endpoints only")
            
        self.exchange = ccxt.binance(exchange_config)
        self.cache_dir = Path('data_cache')
        self.cache_dir.mkdir(exist_ok=True)
 
    def get_all_spot_usdt_pairs_merged(self) -> List[str]:
        """Get all spot USDT trading pairs from Binance with API access"""
        try:
            # Load markets to get comprehensive list
            markets = self.exchange.load_markets()
            usdt_pairs = []
            
            for symbol, market in markets.items():
                if (market.get('type') == 'spot' and 
                    market.get('quote') == 'USDT' and 
                    market.get('active', False)):
                    usdt_pairs.append(symbol)
            
            if not usdt_pairs:
                logger.warning("No USDT pairs found, using fallback list")
                return self._get_fallback_pairs()
            
            logger.info(f"Found {len(usdt_pairs)} active USDT spot pairs")
            
            # Sort by volume for better prioritization (only if we have API access)
            try:
                merged_usdt_pairs = []
                total_pairs = len(usdt_pairs)
                batch_size = 100

                for i in range(0, total_pairs, batch_size):
                    top_pairs = usdt_pairs[i:i+batch_size]
                    tickers = self.exchange.fetch_tickers(top_pairs)
                    merged_usdt_pairs.extend(top_pairs)
                    logger.info(f"Fetched batch {i//batch_size+1}: {len(top_pairs)} pairs")
                    time.sleep(3)  # Sleep to avoid rate limit

                # Sort merged_usdt_pairs by trading volume at the end
                all_tickers = self.exchange.fetch_tickers(merged_usdt_pairs)
                usdt_pairs = sorted(merged_usdt_pairs, key=lambda x: all_tickers.get(x, {}).get('quoteVolume', 0), reverse=True)
                logger.info("Merged and sorted all pairs by trading volume")

            except Exception as e:
                logger.warning(f"Could not sort by volume: {e}")
            
            return usdt_pairs
            
        except Exception as e:
            logger.error(f"Error fetching spot pairs: {e}")
            return self._get_fallback_pairs()
           
    def get_all_spot_usdt_pairs(self) -> List[str]:
        """Get all spot USDT trading pairs from Binance with API access"""
        try:
            # Load markets to get comprehensive list
            markets = self.exchange.load_markets()
            usdt_pairs = []
            
            for symbol, market in markets.items():
                if (market.get('type') == 'spot' and 
                    market.get('quote') == 'USDT' and 
                    market.get('active', False)):
                    usdt_pairs.append(symbol)
            
            if not usdt_pairs:
                logger.warning("No USDT pairs found, using fallback list")
                return self._get_fallback_pairs()
            
            logger.info(f"Found {len(usdt_pairs)} active USDT spot pairs")
            
            # Sort by volume for better prioritization (only if we have API access)
            try:
                # Limit to top 100 pairs to avoid rate limits
                # top_pairs = usdt_pairs[:100]
                # top_pairs = usdt_pairs[100:200]
                top_pairs = usdt_pairs[200:300]
                # top_pairs = usdt_pairs[300:400]
                # top_pairs = usdt_pairs[400:419]

                tickers = self.exchange.fetch_tickers(top_pairs)
                usdt_pairs.sort(key=lambda x: tickers.get(x, {}).get('quoteVolume', 0), reverse=True)
                logger.info("Sorted pairs by trading volume")
            except Exception as e:
                logger.warning(f"Could not sort by volume: {e}")
            
            return usdt_pairs
            
        except Exception as e:
            logger.error(f"Error fetching spot pairs: {e}")
            return self._get_fallback_pairs()
    
    def _get_fallback_pairs(self) -> List[str]:
        """Get fallback list of major USDT pairs"""
        logger.info("Using fallback list of major USDT pairs")
        return [
            'BTC/USDT', 'ETH/USDT', 'BNB/USDT', 'ADA/USDT', 'XRP/USDT',
            'SOL/USDT', 'DOT/USDT', 'DOGE/USDT', 'AVAX/USDT', 'SHIB/USDT',
            'MATIC/USDT', 'LTC/USDT', 'UNI/USDT', 'LINK/USDT', 'ATOM/USDT',
            'XLM/USDT', 'BCH/USDT', 'FIL/USDT', 'TRX/USDT', 'ETC/USDT',
            'VET/USDT', 'ICP/USDT', 'THETA/USDT', 'FTM/USDT', 'ALGO/USDT',
            'MANA/USDT', 'SAND/USDT', 'AXS/USDT', 'CRV/USDT', 'COMP/USDT',
            'MKR/USDT', 'SNX/USDT', 'YFI/USDT', 'AAVE/USDT', 'SUSHI/USDT'
        ]
    
    def fetch_ohlcv_data(self, symbol: str, timeframe: str = '1d', 
                        years: int = 1) -> Optional[pd.DataFrame]:
        """Fetch OHLCV data for a symbol with caching and robust error handling"""
        try:
            # Input validation
            if not symbol or not isinstance(symbol, str):
                logger.error(f"Invalid symbol: {symbol}")
                return None
            
            if years <= 0 or years > 5:  # Limit to reasonable range
                logger.warning(f"Invalid years parameter: {years}, using 1 year")
                years = 1
            
            # Check cache first
            cache_file = self.cache_dir / f"{symbol.replace('/', '_')}_{timeframe}_{years}y.json"
            
            if cache_file.exists():
                cache_time = datetime.fromtimestamp(cache_file.stat().st_mtime)
                if datetime.now() - cache_time < timedelta(hours=1):  # Cache valid for 1 hour
                    logger.info(f"Loading {symbol} from cache")
                    try:
                        with open(cache_file, 'r') as f:
                            data = json.load(f)
                            df = pd.DataFrame(data)
                            if not df.empty:
                                return df
                    except Exception as e:
                        logger.warning(f"Error loading cache for {symbol}: {e}")
            
            # Calculate start date for historical data
            end_date = datetime.now()
            start_date = end_date - timedelta(days=years * 365)
            
            # Convert to timestamp
            from_ts = self.exchange.parse8601(start_date.strftime('%Y-%m-%d %H:%M:%S'))
            
            # Fetch data with pagination
            ohlcv_list = self._fetch_ohlcv_paginated(symbol, timeframe, from_ts)
            
            if not ohlcv_list:
                logger.warning(f"No data fetched for {symbol}")
                return None
            
            # Convert to DataFrame
            df = pd.DataFrame(ohlcv_list, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
            df = df.sort_values('timestamp').drop_duplicates(subset=['timestamp'])
            df = df.reset_index(drop=True)
            
            # Validate data quality
            if len(df) < 30:  # Need at least 30 days
                logger.warning(f"Insufficient data for {symbol}: {len(df)} days")
                return None
            
            # Cache the data
            try:
                with open(cache_file, 'w') as f:
                    json.dump(df.to_dict('records'), f, default=str)
            except Exception as e:
                logger.warning(f"Error caching data for {symbol}: {e}")
            
            logger.info(f"Fetched {len(df)} candles for {symbol}")
            return df
            
        except Exception as e:
            logger.error(f"Error fetching OHLCV for {symbol}: {e}")
            return None
    
    def _fetch_ohlcv_paginated(self, symbol: str, timeframe: str, from_ts: int) -> List:
        """Fetch OHLCV data with pagination and rate limiting"""
        ohlcv_list = []
        max_candles = 1000  # Reasonable limit for 1 year of daily data
        
        try:
            # First request
            ohlcv = self.exchange.fetch_ohlcv(symbol, timeframe, since=from_ts, limit=1000)
            if ohlcv:
                ohlcv_list.extend(ohlcv)
            
            # Pagination loop
            while len(ohlcv_list) < max_candles:
                if not ohlcv or len(ohlcv) < 1000:
                    break
                
                # Get the last timestamp and request next batch
                from_ts = ohlcv[-1][0] + 1  # Add 1ms to avoid duplicates
                ohlcv = self.exchange.fetch_ohlcv(symbol, timeframe, since=from_ts, limit=1000)
                
                if not ohlcv or len(ohlcv) == 0:
                    break
                
                ohlcv_list.extend(ohlcv)
                
                # Rate limiting
                time.sleep(0.1)
                
                # Safety check
                if len(ohlcv_list) > max_candles:
                    ohlcv_list = ohlcv_list[:max_candles]
                    break
            
            return ohlcv_list
            
        except Exception as e:
            logger.warning(f"Error in pagination for {symbol}: {e}")
            return ohlcv_list
    
    def get_current_ticker_data(self, symbol: str) -> Optional[Dict]:
        """Get current ticker data for a symbol using the exact pattern from your example"""
        try:
            ticker = self.exchange.fetch_ticker(symbol)
            return ticker
        except Exception as e:
            logger.warning(f"Error fetching ticker for {symbol}: {e}")
            return None
    
    def calculate_volume_7d_usd(self, df: pd.DataFrame) -> float:
        """Calculate 7-day trading volume in USD with validation"""
        try:
            if df is None or df.empty:
                logger.warning("Empty DataFrame provided for volume calculation")
                return 0.0
            
            if len(df) < 7:
                logger.warning(f"Insufficient data for 7d volume calculation: {len(df)} days")
                return 0.0
            
            # Validate required columns
            required_cols = ['volume', 'close']
            if not all(col in df.columns for col in required_cols):
                logger.error(f"Missing required columns: {required_cols}")
                return 0.0
            
            # Get last 7 days of data
            last_7_days = df.tail(7)
            
            # Check for valid data
            if last_7_days['volume'].isna().any() or last_7_days['close'].isna().any():
                logger.warning("NaN values found in volume or close data")
                return 0.0
            
            # Calculate volume in USD (volume * close_price)
            volume_usd = (last_7_days['volume'] * last_7_days['close']).sum()
            
            # Validate result
            if volume_usd < 0:
                logger.warning("Negative volume calculated, returning 0")
                return 0.0
            
            return float(volume_usd)
            
        except Exception as e:
            logger.error(f"Error calculating 7d volume: {e}")
            return 0.0

class MarketScreener:
    """Main market screener class - clean and simple"""
    
    def __init__(self, api_key: Optional[str] = None, api_secret: Optional[str] = None):
        self.data_fetcher = BinanceDataFetcher(api_key, api_secret)
        self.hurst_calculator = HurstCalculator()
        self.criteria = ScreeningCriteria()
        self.results: List[PairData] = []
        
    def screen_single_pair(self, symbol: str) -> Optional[PairData]:
        """Screen a single trading pair with comprehensive validation and error handling"""
        try:
            # Input validation
            if not symbol or not isinstance(symbol, str):
                logger.error(f"Invalid symbol: {symbol}")
                return None
            
            logger.info(f"Screening {symbol}...")
            
            # Step 1: Get current ticker data for quick filters
            ticker_data = self.data_fetcher.get_current_ticker_data(symbol)
            if not ticker_data:
                logger.warning(f"No ticker data available for {symbol}")
                return None
            
            # Step 2: Price filter (quick)
            current_price = ticker_data.get('last', 0)
            if current_price <= 0:
                logger.warning(f"Invalid price for {symbol}: {current_price}")
                return None
            
            if current_price < self.criteria.min_price:
                logger.debug(f"{symbol} filtered out: price ${current_price:.4f} < ${self.criteria.min_price}")
                return None
            
            # Step 3: Volume pre-filter (quick)
            volume_24h = ticker_data.get('quoteVolume', 0)
            if volume_24h <= 0:
                logger.warning(f"Invalid volume for {symbol}: {volume_24h}")
                return None
            
            # Quick volume check (24h volume * 7 should be roughly 7d volume)
            estimated_7d_volume = volume_24h * 7
            if estimated_7d_volume < self.criteria.min_volume_7d_usd * 0.5:  # Conservative estimate
                logger.debug(f"{symbol} filtered out: estimated 7d volume ${estimated_7d_volume:,.0f} too low")
                return None
            
            # Step 4: Fetch OHLCV data for detailed analysis
            df = self.data_fetcher.fetch_ohlcv_data(symbol, years=self.criteria.years_of_data)
            if df is None or df.empty:
                logger.warning(f"No OHLCV data available for {symbol}")
                return None
            
            # Step 5: Data quality check
            if len(df) < 30:  # At least 30 days of data
                logger.warning(f"Insufficient data for {symbol}: {len(df)} days")
                return None
            
            # Step 6: Calculate 7-day volume in USD (detailed check)
            volume_7d_usd = self.data_fetcher.calculate_volume_7d_usd(df)
            if volume_7d_usd < self.criteria.min_volume_7d_usd:
                logger.debug(f"{symbol} filtered out: 7d volume ${volume_7d_usd:,.0f} < ${self.criteria.min_volume_7d_usd:,.0f}")
                return None
            
            # Step 7: Calculate Hurst exponent
            hurst = self.hurst_calculator.calculate_hurst(df['close'])
            if hurst >= self.criteria.max_hurst:
                logger.debug(f"{symbol} filtered out: Hurst {hurst:.4f} >= {self.criteria.max_hurst}")
                return None
            
            # Step 8: Calculate 7-day volume in base currency
            volume_7d = df.tail(7)['volume'].sum()
            
            # Step 9: Create pair data
            pair_data = PairData(
                symbol=symbol,
                close_price=current_price,
                hurst_exponent=hurst,
                volume_7d=volume_7d,
                volume_7d_usd=volume_7d_usd,
                last_update=datetime.now(),
                ohlcv_data=df
            )
            
            logger.info(f"✅ {symbol} passed all filters: "
                       f"Price=${current_price:.4f}, "
                       f"Hurst={hurst:.4f}, "
                       f"7d Volume=${volume_7d_usd:,.0f}")
            
            return pair_data
            
        except Exception as e:
            logger.error(f"Error screening {symbol}: {e}")
            return None
    
    def screen_all_pairs(self, max_workers: int = 3) -> List[PairData]:
        """Screen all USDT spot pairs with parallel processing and comprehensive error handling"""
        try:
            # Input validation
            if max_workers <= 0 or max_workers > 10:
                logger.warning(f"Invalid max_workers: {max_workers}, using 3")
                max_workers = 3
            
            # Get all USDT pairs
            pairs = self.data_fetcher.get_all_spot_usdt_pairs()
            # pairs = self.data_fetcher.get_all_spot_usdt_pairs_merged()
            
            if not pairs:
                logger.error("No pairs found to screen")
                return []
            
            # Limit pairs for performance (focus on top liquid pairs)
            max_pairs = 50  # Screen top 50 most liquid pairs
            if len(pairs) > max_pairs:
                pairs = pairs[:max_pairs]
                logger.info(f"Limited screening to top {max_pairs} most liquid pairs")
            
            logger.info(f"Starting screening of {len(pairs)} pairs with {max_workers} workers...")
            
            # Screen pairs in parallel
            results = []
            completed = 0
            total = len(pairs)
            
            with ThreadPoolExecutor(max_workers=max_workers) as executor:
                # Submit all tasks
                future_to_pair = {
                    executor.submit(self.screen_single_pair, pair): pair 
                    for pair in pairs
                }
                
                # Process completed tasks
                for future in as_completed(future_to_pair):
                    pair = future_to_pair[future]
                    completed += 1
                    
                    try:
                        result = future.result(timeout=30)  # 30 second timeout per pair
                        if result:
                            results.append(result)
                            logger.info(f"Progress: {completed}/{total} - Found {len(results)} valid pairs")
                    except Exception as e:
                        logger.error(f"Error processing {pair}: {e}")
                        continue
                    
                    # Progress update every 10 pairs
                    if completed % 10 == 0:
                        logger.info(f"Progress: {completed}/{total} pairs processed")
            
            # Sort by volume (descending) and take top N
            results.sort(key=lambda x: x.volume_7d_usd, reverse=True)
            top_results = results[:self.criteria.top_n_pairs]
            
            self.results = top_results
            logger.info(f"Screening completed. {len(results)} pairs passed filters.")
            logger.info(f"Top {len(top_results)} pairs selected.")
            
            return top_results
            
        except Exception as e:
            logger.error(f"Error in screening process: {e}")
            return []

    def screen_all_pairs_merged(self, max_workers: int = 3) -> List[PairData]:
        """Screen all USDT spot pairs with parallel processing and comprehensive error handling"""
        try:
            # Input validation
            if max_workers <= 0 or max_workers > 10:
                logger.warning(f"Invalid max_workers: {max_workers}, using 3")
                max_workers = 3
            
            # Get all USDT pairs
            # pairs = self.data_fetcher.get_all_spot_usdt_pairs()
            pairs = self.data_fetcher.get_all_spot_usdt_pairs_merged()
            
            if not pairs:
                logger.error("No pairs found to screen")
                return []
            
            # Process pairs in batches of 50 for performance
            batch_size = 50
            results = []
            total = len(pairs)
            completed = 0

            for batch_start in range(0, total, batch_size):
                batch_pairs = pairs[batch_start:batch_start + batch_size]
                logger.info(f"Processing batch {batch_start // batch_size + 1}: {len(batch_pairs)} pairs")

                with ThreadPoolExecutor(max_workers=max_workers) as executor:
                    future_to_pair = {
                        executor.submit(self.screen_single_pair, pair): pair
                        for pair in batch_pairs
                    }

                    for future in as_completed(future_to_pair):
                        pair = future_to_pair[future]
                        completed += 1
                        try:
                            result = future.result(timeout=30)
                            if result:
                                results.append(result)
                                logger.info(f"Progress: {completed}/{total} - Found {len(results)} valid pairs")
                        except Exception as e:
                            logger.error(f"Error processing {pair}: {e}")
                            continue

                        if completed % 10 == 0:
                            logger.info(f"Progress: {completed}/{total} pairs processed")
                            
            # Sort by volume (descending) and take top N
            results.sort(key=lambda x: x.volume_7d_usd, reverse=True)
            top_results = results[:self.criteria.top_n_pairs]
            
            self.results = top_results
            logger.info(f"Screening completed. {len(results)} pairs passed filters.")
            logger.info(f"Top {len(top_results)} pairs selected.")
            
            return top_results
            
        except Exception as e:
            logger.error(f"Error in screening process: {e}")
            return []

    def get_screening_summary(self) -> Dict:
        """Get summary of screening results"""
        if not self.results:
            return {"message": "No results available"}
        
        summary = {
            "total_pairs_screened": len(self.results),
            "criteria": {
                "min_price": self.criteria.min_price,
                "min_volume_7d_usd": self.criteria.min_volume_7d_usd,
                "max_hurst": self.criteria.max_hurst,
                "years_of_data": self.criteria.years_of_data
            },
            "top_pairs": []
        }
        
        for i, pair in enumerate(self.results, 1):
            summary["top_pairs"].append({
                "rank": i,
                "symbol": pair.symbol,
                "close_price": pair.close_price,
                "hurst_exponent": pair.hurst_exponent,
                "volume_7d_usd": pair.volume_7d_usd,
                "volume_7d": pair.volume_7d
            })
        
        return summary
    
    def save_results(self, filename: str = "screening_results.json"):
        """Save screening results to file"""
        try:
            results_data = {
                "timestamp": datetime.now().isoformat(),
                "summary": self.get_screening_summary(),
                "detailed_results": []
            }
            
            for pair in self.results:
                results_data["detailed_results"].append({
                    "symbol": pair.symbol,
                    "close_price": pair.close_price,
                    "hurst_exponent": pair.hurst_exponent,
                    "volume_7d_usd": pair.volume_7d_usd,
                    "volume_7d": pair.volume_7d,
                    "last_update": pair.last_update.isoformat()
                })
            
            with open(filename, 'w') as f:
                json.dump(results_data, f, indent=2, default=str)
            
            logger.info(f"Results saved to {filename}")
            
        except Exception as e:
            logger.error(f"Error saving results: {e}")

def main():
    """Main function to run the market screener - clean and simple"""
    try:
        logger.info("🚀 Starting Market Screener for Grid Trading Pairs")
        logger.info("=" * 60)
        
        # Load API credentials
        api_key, api_secret = _load_api_credentials()
        
        # Initialize screener
        screener = MarketScreener(api_key=api_key, api_secret=api_secret)
        
        # Run screening
        start_time = time.time()
        # results = screener.screen_all_pairs(max_workers=3)
        results = screener.screen_all_pairs_merged(max_workers=3)
        
        end_time = time.time()
        duration = end_time - start_time
        
        # Display results
        _display_results(results, duration)
        
        # Save results
        screener.save_results()
        
        # Display summary
        _display_summary(screener)
        
    except KeyboardInterrupt:
        logger.info("\n⏹️  Screening interrupted by user")
    except Exception as e:
        logger.error(f"❌ Fatal error in main: {e}")
        raise

def _load_api_credentials() -> Tuple[Optional[str], Optional[str]]:
    """Load API credentials with error handling"""
    try:
        from api_config import get_api_credentials
        api_key, api_secret = get_api_credentials()
        
        if not api_key or not api_secret:
            logger.error("❌ API credentials not configured!")
            logger.info("Please update api_config.py with your Binance API credentials")
            return None, None
        else:
            logger.info("✅ API credentials loaded successfully")
            return api_key, api_secret
            
    except ImportError:
        logger.warning("⚠️  api_config.py not found, running without API credentials")
        return None, None

def _display_results(results: List[PairData], duration: float) -> None:
    """Display screening results"""
    logger.info(f"\n⏱️  Screening completed in {duration:.2f} seconds")
    logger.info(f"📊 Found {len(results)} pairs that passed all criteria")
    
    if results:
        logger.info("\n🏆 TOP PAIRS FOR GRID TRADING:")
        logger.info("-" * 60)
        
        for i, pair in enumerate(results, 1):
            logger.info(f"{i}. {pair.symbol}")
            logger.info(f"   💰 Price: ${pair.close_price:.4f}")
            logger.info(f"   📈 Hurst: {pair.hurst_exponent:.4f}")
            logger.info(f"   💵 7d Volume: ${pair.volume_7d_usd:,.0f}")
            logger.info(f"   📊 7d Volume (base): {pair.volume_7d:,.2f}")
            logger.info("")
    else:
        logger.warning("❌ No pairs found that meet the criteria")

def _display_summary(screener: MarketScreener) -> None:
    """Display screening summary"""
    summary = screener.get_screening_summary()
    if "criteria" in summary:
        logger.info("📋 SCREENING SUMMARY:")
        logger.info(f"   Min Price: ${summary['criteria']['min_price']}")
        logger.info(f"   Min 7d Volume: ${summary['criteria']['min_volume_7d_usd']:,.0f}")
        logger.info(f"   Max Hurst: {summary['criteria']['max_hurst']}")
        logger.info(f"   Data Period: {summary['criteria']['years_of_data']} years")

if __name__ == "__main__":
    main()
# Out:
# 2025-09-28 07:58:22,925 - INFO - 🚀 Starting Market Screener for Grid Trading Pairs
# 2025-09-28 07:58:22,926 - INFO - ============================================================
# 2025-09-28 07:58:22,931 - INFO - ✅ API credentials loaded successfully
# 2025-09-28 07:58:22,932 - INFO - 🔑 Using API credentials for enhanced data access
# 2025-09-28 07:58:25,169 - INFO - Found 423 active USDT spot pairs
# 2025-09-28 07:58:25,254 - INFO - Fetched batch 1: 100 pairs
# 2025-09-28 07:58:28,339 - INFO - Fetched batch 2: 100 pairs
# 2025-09-28 07:58:31,562 - INFO - Fetched batch 3: 100 pairs
# 2025-09-28 07:58:34,654 - INFO - Fetched batch 4: 100 pairs
# 2025-09-28 07:58:37,734 - INFO - Fetched batch 5: 23 pairs
# 2025-09-28 07:58:40,855 - INFO - Merged and sorted all pairs by trading volume
# 2025-09-28 07:58:40,856 - INFO - Processing batch 1: 50 pairs
# 2025-09-28 07:58:40,857 - INFO - Screening XPL/USDT...
# 2025-09-28 07:58:40,858 - INFO - Screening USDC/USDT...
# 2025-09-28 07:58:40,860 - INFO - Screening ETH/USDT...
# 2025-09-28 07:58:40,979 - INFO - Screening BTC/USDT...
# 2025-09-28 07:58:41,082 - WARNING - Insufficient data for XPL/USDT: 4 days
# 2025-09-28 07:58:41,083 - WARNING - No OHLCV data available for XPL/USDT
# 2025-09-28 07:58:41,084 - INFO - Screening SOL/USDT...
# 2025-09-28 07:58:41,097 - INFO - Fetched 365 candles for ETH/USDT
# 2025-09-28 07:58:41,102 - INFO - Screening USDE/USDT...
# 2025-09-28 07:58:41,180 - INFO - Fetched 365 candles for BTC/USDT
# 2025-09-28 07:58:41,182 - INFO - Screening AVNT/USDT...
# 2025-09-28 07:58:41,284 - INFO - Fetched 365 candles for SOL/USDT
# 2025-09-28 07:58:41,289 - INFO - Screening BNB/USDT...
# 2025-09-28 07:58:41,290 - WARNING - Insufficient data for USDE/USDT: 20 days
# 2025-09-28 07:58:41,293 - WARNING - No OHLCV data available for USDE/USDT
# 2025-09-28 07:58:41,296 - INFO - Screening XRP/USDT...
# 2025-09-28 07:58:41,355 - WARNING - Insufficient data for AVNT/USDT: 14 days
# 2025-09-28 07:58:41,356 - WARNING - No OHLCV data available for AVNT/USDT
# 2025-09-28 07:58:41,356 - INFO - Screening ALPINE/USDT...
# 2025-09-28 07:58:41,467 - INFO - Fetched 365 candles for BNB/USDT
# 2025-09-28 07:58:41,469 - INFO - ✅ BNB/USDT passed all filters: Price=$969.6000, Hurst=0.4993, 7d Volume=$2,644,735,811
# 2025-09-28 07:58:41,470 - INFO - Screening DOGE/USDT...
# 2025-09-28 07:58:41,470 - INFO - Progress: 8/423 - Found 1 valid pairs
# 2025-09-28 07:58:41,487 - INFO - Fetched 365 candles for XRP/USDT
# 2025-09-28 07:58:41,490 - INFO - Screening MIRA/USDT...
# 2025-09-28 07:58:41,520 - INFO - Fetched 365 candles for ALPINE/USDT
# 2025-09-28 07:58:41,522 - INFO - Screening 1000SATS/USDT...
# 2025-09-28 07:58:41,522 - INFO - Progress: 10/423 pairs processed
# 2025-09-28 07:58:41,546 - INFO - Screening FDUSD/USDT...
# 2025-09-28 07:58:41,597 - INFO - Screening KAITO/USDT...
# 2025-09-28 07:58:41,622 - INFO - Screening AEVO/USDT...
# 2025-09-28 07:58:41,644 - WARNING - Insufficient data for MIRA/USDT: 3 days
# 2025-09-28 07:58:41,645 - WARNING - No OHLCV data available for MIRA/USDT
# 2025-09-28 07:58:41,645 - INFO - Screening ZKC/USDT...
# 2025-09-28 07:58:41,699 - INFO - Screening PUMP/USDT...
# 2025-09-28 07:58:41,722 - INFO - Screening LINEA/USDT...
# 2025-09-28 07:58:41,762 - INFO - Fetched 221 candles for KAITO/USDT
# 2025-09-28 07:58:41,764 - INFO - Screening SUI/USDT...
# 2025-09-28 07:58:41,776 - INFO - Screening AVAX/USDT...
# 2025-09-28 07:58:41,800 - INFO - Screening WLFI/USDT...
# 2025-09-28 07:58:41,879 - INFO - Screening TRX/USDT...
# 2025-09-28 07:58:41,879 - INFO - Progress: 20/423 pairs processed
# 2025-09-28 07:58:41,930 - INFO - Fetched 365 candles for SUI/USDT
# 2025-09-28 07:58:41,932 - INFO - Screening THE/USDT...
# 2025-09-28 07:58:41,953 - INFO - Fetched 365 candles for AVAX/USDT
# 2025-09-28 07:58:41,955 - INFO - Screening PEPE/USDT...
# 2025-09-28 07:58:41,960 - INFO - Screening BARD/USDT...
# 2025-09-28 07:58:42,008 - INFO - Screening HEMI/USDT...
# 2025-09-28 07:58:42,032 - INFO - Screening EIGEN/USDT...
# 2025-09-28 07:58:42,085 - INFO - Screening ADA/USDT...
# 2025-09-28 07:58:42,130 - WARNING - Insufficient data for BARD/USDT: 11 days
# 2025-09-28 07:58:42,130 - WARNING - No OHLCV data available for BARD/USDT
# 2025-09-28 07:58:42,131 - INFO - Screening OG/USDT...
# 2025-09-28 07:58:42,212 - INFO - Fetched 363 candles for EIGEN/USDT
# 2025-09-28 07:58:42,215 - INFO - Screening WLD/USDT...
# 2025-09-28 07:58:42,299 - INFO - Fetched 365 candles for OG/USDT
# 2025-09-28 07:58:42,301 - INFO - Screening SNX/USDT...
# 2025-09-28 07:58:42,303 - INFO - Screening 0G/USDT...
# 2025-09-28 07:58:42,303 - INFO - Progress: 30/423 pairs processed
# 2025-09-28 07:58:42,480 - INFO - Fetched 365 candles for SNX/USDT
# 2025-09-28 07:58:42,481 - WARNING - Insufficient data for 0G/USDT: 7 days
# 2025-09-28 07:58:42,484 - WARNING - No OHLCV data available for 0G/USDT
# 2025-09-28 07:58:42,483 - INFO - Screening APT/USDT...
# 2025-09-28 07:58:42,485 - INFO - Screening USD1/USDT...
# 2025-09-28 07:58:42,582 - INFO - Screening ENA/USDT...
# 2025-09-28 07:58:42,620 - INFO - Fetched 365 candles for WLD/USDT
# 2025-09-28 07:58:42,622 - INFO - Screening ORDI/USDT...
# 2025-09-28 07:58:42,654 - INFO - Fetched 365 candles for APT/USDT
# 2025-09-28 07:58:42,656 - INFO - Screening SKL/USDT...
# 2025-09-28 07:58:42,659 - INFO - Screening PENGU/USDT...
# 2025-09-28 07:58:42,733 - INFO - Screening LINK/USDT...
# 2025-09-28 07:58:42,754 - INFO - Screening ETHFI/USDT...
# 2025-09-28 07:58:43,104 - INFO - Fetched 365 candles for LINK/USDT
# 2025-09-28 07:58:43,106 - INFO - Screening OM/USDT...
# 2025-09-28 07:58:43,130 - INFO - Fetched 365 candles for ETHFI/USDT
# 2025-09-28 07:58:43,132 - INFO - Screening SOMI/USDT...
# 2025-09-28 07:58:43,132 - INFO - Progress: 40/423 pairs processed
# 2025-09-28 07:58:43,149 - INFO - Fetched 365 candles for ORDI/USDT
# 2025-09-28 07:58:43,151 - INFO - Screening UNI/USDT...
# 2025-09-28 07:58:43,209 - INFO - Screening NEAR/USDT...
# 2025-09-28 07:58:43,322 - INFO - Screening SOLV/USDT...
# 2025-09-28 07:58:43,399 - INFO - Screening SUN/USDT...
# 2025-09-28 07:58:43,476 - INFO - Screening ZRO/USDT...
# 2025-09-28 07:58:43,528 - INFO - Fetched 365 candles for UNI/USDT
# 2025-09-28 07:58:43,539 - INFO - Screening LTC/USDT...
# 2025-09-28 07:58:43,720 - INFO - Fetched 365 candles for NEAR/USDT
# 2025-09-28 07:58:43,722 - INFO - Fetched 365 candles for LTC/USDT
# 2025-09-28 07:58:43,723 - INFO - Screening SEI/USDT...
# 2025-09-28 07:58:43,725 - INFO - ✅ LTC/USDT passed all filters: Price=$104.1000, Hurst=0.4992, 7d Volume=$255,793,697
# 2025-09-28 07:58:43,728 - INFO - Progress: 48/423 - Found 2 valid pairs
# 2025-09-28 07:58:43,860 - INFO - Fetched 365 candles for ZRO/USDT
# 2025-09-28 07:58:43,862 - INFO - Progress: 50/423 pairs processed
# 2025-09-28 07:58:43,863 - INFO - Processing batch 2: 50 pairs
# 2025-09-28 07:58:43,864 - INFO - Screening PROVE/USDT...
# 2025-09-28 07:58:43,865 - INFO - Screening W/USDT...
# 2025-09-28 07:58:43,866 - INFO - Screening HBAR/USDT...
# 2025-09-28 07:58:43,938 - INFO - Screening IMX/USDT...
# 2025-09-28 07:58:43,956 - INFO - Screening ARB/USDT...
# 2025-09-28 07:58:43,958 - INFO - Screening EDU/USDT...
# 2025-09-28 07:58:44,035 - INFO - Screening BONK/USDT...
# 2025-09-28 07:58:44,109 - INFO - Screening FORM/USDT...
# 2025-09-28 07:58:44,158 - INFO - Screening AAVE/USDT...
# 2025-09-28 07:58:44,170 - INFO - Screening TWT/USDT...
# 2025-09-28 07:58:44,285 - INFO - Fetched 194 candles for FORM/USDT
# 2025-09-28 07:58:44,288 - INFO - Screening WOO/USDT...
# 2025-09-28 07:58:44,364 - INFO - Screening TRUMP/USDT...
# 2025-09-28 07:58:44,474 - INFO - Fetched 365 candles for AAVE/USDT
# 2025-09-28 07:58:44,476 - INFO - Screening DOT/USDT...
# 2025-09-28 07:58:44,476 - INFO - Progress: 60/423 pairs processed
# 2025-09-28 07:58:44,562 - INFO - Fetched 365 candles for TWT/USDT
# 2025-09-28 07:58:44,564 - INFO - Screening TAO/USDT...
# 2025-09-28 07:58:44,711 - INFO - Fetched 365 candles for DOT/USDT
# 2025-09-28 07:58:44,713 - INFO - Screening CRV/USDT...
# 2025-09-28 07:58:44,746 - INFO - Fetched 253 candles for TRUMP/USDT
# 2025-09-28 07:58:44,749 - INFO - Screening OPEN/USDT...
# 2025-09-28 07:58:44,788 - INFO - Screening ONDO/USDT...
# 2025-09-28 07:58:44,824 - INFO - Screening OP/USDT...
# 2025-09-28 07:58:44,899 - INFO - Screening HOLO/USDT...
# 2025-09-28 07:58:44,938 - INFO - Fetched 365 candles for TAO/USDT
# 2025-09-28 07:58:44,940 - INFO - Screening TON/USDT...
# 2025-09-28 07:58:44,974 - INFO - Screening TUT/USDT...
# 2025-09-28 07:58:45,000 - INFO - Screening TIA/USDT...
# 2025-09-28 07:58:45,050 - INFO - Screening COW/USDT...
# 2025-09-28 07:58:45,050 - INFO - Progress: 70/423 pairs processed
# 2025-09-28 07:58:45,124 - INFO - Screening SPK/USDT...
# 2025-09-28 07:58:45,232 - INFO - Fetched 365 candles for TIA/USDT
# 2025-09-28 07:58:45,234 - INFO - ✅ TIA/USDT passed all filters: Price=$1.3890, Hurst=0.4849, 7d Volume=$95,738,625
# 2025-09-28 07:58:45,235 - INFO - Screening CAKE/USDT...
# 2025-09-28 07:58:45,235 - INFO - Progress: 72/423 - Found 3 valid pairs
# 2025-09-28 07:58:45,319 - INFO - Fetched 365 candles for TON/USDT
# 2025-09-28 07:58:45,321 - INFO - Screening WIF/USDT...
# 2025-09-28 07:58:45,336 - INFO - Screening FIL/USDT...
# 2025-09-28 07:58:45,411 - INFO - Screening BB/USDT...
# 2025-09-28 07:58:45,412 - INFO - Fetched 365 candles for CAKE/USDT
# 2025-09-28 07:58:45,415 - INFO - Screening OMNI/USDT...
# 2025-09-28 07:58:45,489 - INFO - Screening YGG/USDT...
# 2025-09-28 07:58:45,522 - INFO - Fetched 365 candles for FIL/USDT
# 2025-09-28 07:58:45,524 - INFO - Screening DYDX/USDT...
# 2025-09-28 07:58:45,563 - INFO - Screening XLM/USDT...
# 2025-09-28 07:58:45,605 - INFO - Screening LISTA/USDT...
# 2025-09-28 07:58:45,606 - INFO - Progress: 80/423 pairs processed
# 2025-09-28 07:58:45,638 - INFO - Screening SHIB/USDT...
# 2025-09-28 07:58:45,667 - INFO - Fetched 365 candles for OMNI/USDT
# 2025-09-28 07:58:45,669 - INFO - Screening BCH/USDT...
# 2025-09-28 07:58:45,679 - INFO - Screening GMX/USDT...
# 2025-09-28 07:58:45,712 - INFO - Screening PLUME/USDT...
# 2025-09-28 07:58:45,836 - INFO - Fetched 365 candles for BCH/USDT
# 2025-09-28 07:58:45,839 - INFO - Screening S/USDT...
# 2025-09-28 07:58:45,915 - INFO - Screening PAXG/USDT...
# 2025-09-28 07:58:45,927 - INFO - Screening BERA/USDT...
# 2025-09-28 07:58:45,927 - INFO - Fetched 365 candles for GMX/USDT
# 2025-09-28 07:58:45,930 - INFO - Screening FET/USDT...
# 2025-09-28 07:58:46,012 - INFO - Screening POL/USDT...
# 2025-09-28 07:58:46,098 - INFO - Fetched 235 candles for BERA/USDT
# 2025-09-28 07:58:46,100 - INFO - Screening SANTOS/USDT...
# 2025-09-28 07:58:46,100 - INFO - Progress: 90/423 pairs processed
# 2025-09-28 07:58:46,103 - INFO - Screening EUR/USDT...
# 2025-09-28 07:58:46,148 - INFO - Fetched 365 candles for PAXG/USDT
# 2025-09-28 07:58:46,150 - INFO - ✅ PAXG/USDT passed all filters: Price=$3779.0000, Hurst=0.4962, 7d Volume=$145,482,578
# 2025-09-28 07:58:46,151 - INFO - Screening TST/USDT...
# 2025-09-28 07:58:46,153 - INFO - Progress: 92/423 - Found 4 valid pairs
# 2025-09-28 07:58:46,226 - INFO - Screening ICP/USDT...
# 2025-09-28 07:58:46,266 - INFO - Fetched 365 candles for SANTOS/USDT
# 2025-09-28 07:58:46,268 - INFO - ✅ SANTOS/USDT passed all filters: Price=$1.8810, Hurst=0.4660, 7d Volume=$25,775,827
# 2025-09-28 07:58:46,269 - INFO - Screening NMR/USDT...
# 2025-09-28 07:58:46,269 - INFO - Progress: 94/423 - Found 5 valid pairs
# 2025-09-28 07:58:46,291 - INFO - Fetched 365 candles for EUR/USDT
# 2025-09-28 07:58:46,293 - INFO - Screening XUSD/USDT...
# 2025-09-28 07:58:46,369 - INFO - Screening STO/USDT...
# 2025-09-28 07:58:46,410 - INFO - Fetched 365 candles for ICP/USDT
# 2025-09-28 07:58:46,412 - INFO - Screening QNT/USDT...
# 2025-09-28 07:58:46,504 - INFO - Fetched 365 candles for NMR/USDT
# 2025-09-28 07:58:46,576 - INFO - Fetched 365 candles for QNT/USDT
# 2025-09-28 07:58:46,578 - INFO - Progress: 100/423 pairs processed
# 2025-09-28 07:58:46,580 - INFO - Processing batch 3: 50 pairs
# 2025-09-28 07:58:46,581 - INFO - Screening PNUT/USDT...
# 2025-09-28 07:58:46,581 - INFO - Screening HUMA/USDT...
# 2025-09-28 07:58:46,582 - INFO - Screening RLC/USDT...
# 2025-09-28 07:58:46,657 - INFO - Screening MITO/USDT...
# 2025-09-28 07:58:46,680 - INFO - Screening BFUSD/USDT...
# 2025-09-28 07:58:46,733 - INFO - Screening LDO/USDT...
# 2025-09-28 07:58:46,767 - INFO - Fetched 365 candles for RLC/USDT
# 2025-09-28 07:58:46,769 - INFO - ✅ RLC/USDT passed all filters: Price=$1.1170, Hurst=0.4870, 7d Volume=$11,049,532
# 2025-09-28 07:58:46,770 - INFO - Screening FLOKI/USDT...
# 2025-09-28 07:58:46,770 - INFO - Progress: 104/423 - Found 6 valid pairs
# 2025-09-28 07:58:46,774 - INFO - Screening VIRTUAL/USDT...
# 2025-09-28 07:58:46,845 - INFO - Screening ATOM/USDT...
# 2025-09-28 07:58:46,905 - INFO - Fetched 365 candles for LDO/USDT
# 2025-09-28 07:58:46,907 - INFO - Screening VANA/USDT...
# 2025-09-28 07:58:46,948 - INFO - Fetched 171 candles for VIRTUAL/USDT
# 2025-09-28 07:58:46,950 - INFO - Screening PENDLE/USDT...
# 2025-09-28 07:58:47,017 - INFO - Fetched 365 candles for ATOM/USDT
# 2025-09-28 07:58:47,020 - INFO - Screening MAV/USDT...
# 2025-09-28 07:58:47,069 - INFO - Fetched 287 candles for VANA/USDT
# 2025-09-28 07:58:47,072 - INFO - Screening BIO/USDT...
# 2025-09-28 07:58:47,072 - INFO - Progress: 110/423 pairs processed
# 2025-09-28 07:58:47,094 - INFO - Screening KERNEL/USDT...
# 2025-09-28 07:58:47,131 - INFO - Fetched 365 candles for PENDLE/USDT
# 2025-09-28 07:58:47,133 - INFO - Screening DOLO/USDT...
# 2025-09-28 07:58:47,148 - INFO - Screening NEIRO/USDT...
# 2025-09-28 07:58:47,168 - INFO - Screening KMNO/USDT...
# 2025-09-28 07:58:47,209 - INFO - Screening GALA/USDT...
# 2025-09-28 07:58:47,230 - INFO - Screening MEME/USDT...
# 2025-09-28 07:58:47,249 - INFO - Screening AWE/USDT...
# 2025-09-28 07:58:47,283 - INFO - Screening ASR/USDT...
# 2025-09-28 07:58:47,305 - INFO - Screening RENDER/USDT...
# 2025-09-28 07:58:47,326 - INFO - Screening STG/USDT...
# 2025-09-28 07:58:47,326 - INFO - Progress: 120/423 pairs processed
# 2025-09-28 07:58:47,401 - INFO - Screening C/USDT...
# 2025-09-28 07:58:47,446 - INFO - Fetched 365 candles for ASR/USDT
# 2025-09-28 07:58:47,448 - INFO - Screening ARKM/USDT...
# 2025-09-28 07:58:47,472 - INFO - Fetched 365 candles for RENDER/USDT
# 2025-09-28 07:58:47,474 - INFO - Screening AR/USDT...
# 2025-09-28 07:58:47,477 - INFO - Screening PUNDIX/USDT...
# 2025-09-28 07:58:47,523 - INFO - Screening ETC/USDT...
# 2025-09-28 07:58:47,571 - INFO - Screening SYRUP/USDT...
# 2025-09-28 07:58:47,642 - INFO - Fetched 365 candles for AR/USDT
# 2025-09-28 07:58:47,645 - INFO - Screening RUNE/USDT...
# 2025-09-28 07:58:47,649 - INFO - Screening ACT/USDT...
# 2025-09-28 07:58:47,687 - INFO - Fetched 365 candles for ETC/USDT
# 2025-09-28 07:58:47,689 - INFO - Screening PYTH/USDT...
# 2025-09-28 07:58:47,740 - INFO - Screening WCT/USDT...
# 2025-09-28 07:58:47,740 - INFO - Progress: 130/423 pairs processed
# 2025-09-28 07:58:47,766 - INFO - Screening DEGO/USDT...
# 2025-09-28 07:58:47,815 - INFO - Fetched 365 candles for RUNE/USDT
# 2025-09-28 07:58:47,818 - INFO - Screening CFX/USDT...
# 2025-09-28 07:58:47,820 - INFO - Screening INJ/USDT...
# 2025-09-28 07:58:47,894 - INFO - Screening JUP/USDT...
# 2025-09-28 07:58:47,951 - INFO - Fetched 365 candles for DEGO/USDT
# 2025-09-28 07:58:47,954 - INFO - ✅ DEGO/USDT passed all filters: Price=$1.1130, Hurst=0.4803, 7d Volume=$24,457,080
# 2025-09-28 07:58:47,954 - INFO - Screening WBTC/USDT...
# 2025-09-28 07:58:47,955 - INFO - Progress: 135/423 - Found 7 valid pairs
# 2025-09-28 07:58:47,968 - INFO - Screening ALGO/USDT...
# 2025-09-28 07:58:48,005 - INFO - Fetched 365 candles for INJ/USDT
# 2025-09-28 07:58:48,009 - INFO - Screening HOOK/USDT...
# 2025-09-28 07:58:48,047 - INFO - Screening SIGN/USDT...
# 2025-09-28 07:58:48,082 - INFO - Screening PERP/USDT...
# 2025-09-28 07:58:48,122 - INFO - Fetched 365 candles for WBTC/USDT
# 2025-09-28 07:58:48,124 - INFO - Screening ME/USDT...
# 2025-09-28 07:58:48,124 - INFO - Progress: 140/423 pairs processed
# 2025-09-28 07:58:48,128 - INFO - Screening LAZIO/USDT...
# 2025-09-28 07:58:48,158 - INFO - Screening BROCCOLI714/USDT...
# 2025-09-28 07:58:48,199 - INFO - Screening WBETH/USDT...
# 2025-09-28 07:58:48,221 - INFO - Screening STRK/USDT...
# 2025-09-28 07:58:48,240 - INFO - Screening MUBARAK/USDT...
# 2025-09-28 07:58:48,296 - INFO - Screening C98/USDT...
# 2025-09-28 07:58:48,316 - INFO - Screening GPS/USDT...
# 2025-09-28 07:58:48,367 - INFO - Fetched 365 candles for WBETH/USDT
# 2025-09-28 07:58:48,391 - INFO - Progress: 150/423 pairs processed
# 2025-09-28 07:58:48,392 - INFO - Processing batch 4: 50 pairs
# 2025-09-28 07:58:48,393 - INFO - Screening JUV/USDT...
# 2025-09-28 07:58:48,393 - INFO - Screening VET/USDT...
# 2025-09-28 07:58:48,395 - INFO - Screening ZEC/USDT...
# 2025-09-28 07:58:48,488 - INFO - Screening SFP/USDT...
# 2025-09-28 07:58:48,565 - INFO - Screening USUAL/USDT...
# 2025-09-28 07:58:48,629 - INFO - Fetched 365 candles for JUV/USDT
# 2025-09-28 07:58:48,631 - INFO - ✅ JUV/USDT passed all filters: Price=$1.0730, Hurst=0.4525, 7d Volume=$16,584,772
# 2025-09-28 07:58:48,632 - INFO - Screening IO/USDT...
# 2025-09-28 07:58:48,632 - INFO - Progress: 153/423 - Found 8 valid pairs
# 2025-09-28 07:58:48,640 - INFO - Screening SKY/USDT...
# 2025-09-28 07:58:48,669 - INFO - Fetched 365 candles for ZEC/USDT
# 2025-09-28 07:58:48,671 - INFO - Screening HYPER/USDT...
# 2025-09-28 07:58:48,707 - INFO - Screening TREE/USDT...
# 2025-09-28 07:58:48,729 - INFO - Screening APE/USDT...
# 2025-09-28 07:58:48,747 - INFO - Screening LA/USDT...
# 2025-09-28 07:58:48,789 - INFO - Screening PEOPLE/USDT...
# 2025-09-28 07:58:48,806 - INFO - Screening 1000CAT/USDT...
# 2025-09-28 07:58:48,807 - INFO - Progress: 160/423 pairs processed
# 2025-09-28 07:58:48,826 - INFO - Screening BOME/USDT...
# 2025-09-28 07:58:48,867 - INFO - Screening ALT/USDT...
# 2025-09-28 07:58:48,891 - INFO - Screening ZK/USDT...
# 2025-09-28 07:58:48,906 - INFO - Screening XAI/USDT...
# 2025-09-28 07:58:48,941 - INFO - Screening DEXE/USDT...
# 2025-09-28 07:58:48,970 - INFO - Screening SUSHI/USDT...
# 2025-09-28 07:58:48,989 - INFO - Screening A/USDT...
# 2025-09-28 07:58:49,045 - INFO - Screening PSG/USDT...
# 2025-09-28 07:58:49,064 - INFO - Screening REZ/USDT...
# 2025-09-28 07:58:49,108 - INFO - Fetched 365 candles for DEXE/USDT
# 2025-09-28 07:58:49,110 - INFO - Screening RAY/USDT...
# 2025-09-28 07:58:49,110 - INFO - Progress: 170/423 pairs processed
# 2025-09-28 07:58:49,141 - INFO - Screening AIXBT/USDT...
# 2025-09-28 07:58:49,220 - INFO - Fetched 365 candles for PSG/USDT
# 2025-09-28 07:58:49,221 - INFO - Screening SAND/USDT...
# 2025-09-28 07:58:49,226 - INFO - Screening FTT/USDT...
# 2025-09-28 07:58:49,274 - INFO - Fetched 365 candles for RAY/USDT
# 2025-09-28 07:58:49,277 - INFO - Screening RDNT/USDT...
# 2025-09-28 07:58:49,297 - INFO - Screening RSR/USDT...
# 2025-09-28 07:58:49,318 - INFO - Screening PROM/USDT...
# 2025-09-28 07:58:49,351 - INFO - Screening 1MBABYDOGE/USDT...
# 2025-09-28 07:58:49,372 - INFO - Screening JOE/USDT...
# 2025-09-28 07:58:49,425 - INFO - Screening INIT/USDT...
# 2025-09-28 07:58:49,446 - INFO - Screening TURBO/USDT...
# 2025-09-28 07:58:49,446 - INFO - Progress: 180/423 pairs processed
# 2025-09-28 07:58:49,484 - INFO - Fetched 365 candles for PROM/USDT
# 2025-09-28 07:58:49,487 - INFO - Screening ERA/USDT...
# 2025-09-28 07:58:49,500 - INFO - Screening AI/USDT...
# 2025-09-28 07:58:49,520 - INFO - Screening RESOLV/USDT...
# 2025-09-28 07:58:49,562 - INFO - Screening LAYER/USDT...
# 2025-09-28 07:58:49,581 - INFO - Screening GUN/USDT...
# 2025-09-28 07:58:49,603 - INFO - Screening GRT/USDT...
# 2025-09-28 07:58:49,638 - INFO - Screening DIA/USDT...
# 2025-09-28 07:58:49,658 - INFO - Screening HEI/USDT...
# 2025-09-28 07:58:49,677 - INFO - Screening IOTX/USDT...
# 2025-09-28 07:58:49,711 - INFO - Screening BABY/USDT...
# 2025-09-28 07:58:49,712 - INFO - Progress: 190/423 pairs processed
# 2025-09-28 07:58:49,734 - INFO - Screening HOME/USDT...
# 2025-09-28 07:58:49,758 - INFO - Screening DOGS/USDT...
# 2025-09-28 07:58:49,788 - INFO - Screening ENS/USDT...
# 2025-09-28 07:58:49,808 - INFO - Screening TOWNS/USDT...
# 2025-09-28 07:58:49,832 - INFO - Screening BEAMX/USDT...
# 2025-09-28 07:58:49,882 - INFO - Screening STX/USDT...
# 2025-09-28 07:58:49,909 - INFO - Screening ZEN/USDT...
# 2025-09-28 07:58:49,950 - INFO - Fetched 365 candles for ENS/USDT
# 2025-09-28 07:58:50,076 - INFO - Fetched 365 candles for ZEN/USDT
# 2025-09-28 07:58:50,078 - INFO - Progress: 200/423 pairs processed
# 2025-09-28 07:58:50,080 - INFO - Processing batch 5: 50 pairs
# 2025-09-28 07:58:50,080 - INFO - Screening PARTI/USDT...
# 2025-09-28 07:58:50,082 - INFO - Screening TRB/USDT...
# 2025-09-28 07:58:50,083 - INFO - Screening MOVE/USDT...
# 2025-09-28 07:58:50,157 - INFO - Screening FUN/USDT...
# 2025-09-28 07:58:50,175 - INFO - Screening NEO/USDT...
# 2025-09-28 07:58:50,232 - INFO - Screening ID/USDT...
# 2025-09-28 07:58:50,312 - INFO - Screening EPIC/USDT...
# 2025-09-28 07:58:50,343 - INFO - Fetched 365 candles for TRB/USDT
# 2025-09-28 07:58:50,348 - INFO - Screening SAGA/USDT...
# 2025-09-28 07:58:50,350 - INFO - Fetched 365 candles for NEO/USDT
# 2025-09-28 07:58:50,352 - INFO - Screening HFT/USDT...
# 2025-09-28 07:58:50,424 - INFO - Screening BNSOL/USDT...
# 2025-09-28 07:58:50,444 - INFO - Screening PYR/USDT...
# 2025-09-28 07:58:50,480 - INFO - Fetched 200 candles for EPIC/USDT
# 2025-09-28 07:58:50,484 - INFO - Screening MBL/USDT...
# 2025-09-28 07:58:50,521 - INFO - Screening ALICE/USDT...
# 2025-09-28 07:58:50,521 - INFO - Progress: 210/423 pairs processed
# 2025-09-28 07:58:50,561 - INFO - Screening CITY/USDT...
# 2025-09-28 07:58:50,592 - INFO - Fetched 347 candles for BNSOL/USDT
# 2025-09-28 07:58:50,595 - INFO - Screening EGLD/USDT...
# 2025-09-28 07:58:50,600 - INFO - Screening KAIA/USDT...
# 2025-09-28 07:58:50,638 - INFO - Screening THETA/USDT...
# 2025-09-28 07:58:50,689 - INFO - Screening KDA/USDT...
# 2025-09-28 07:58:50,713 - INFO - Screening BAR/USDT...
# 2025-09-28 07:58:50,771 - INFO - Screening CHZ/USDT...
# 2025-09-28 07:58:50,776 - INFO - Fetched 365 candles for EGLD/USDT
# 2025-09-28 07:58:50,779 - INFO - Screening JTO/USDT...
# 2025-09-28 07:58:50,848 - INFO - Screening SSV/USDT...
# 2025-09-28 07:58:50,912 - INFO - Fetched 365 candles for BAR/USDT
# 2025-09-28 07:58:50,913 - INFO - Screening LUNA/USDT...
# 2025-09-28 07:58:50,915 - INFO - Progress: 220/423 pairs processed
# 2025-09-28 07:58:50,959 - INFO - Fetched 365 candles for JTO/USDT
# 2025-09-28 07:58:50,961 - INFO - ✅ JTO/USDT passed all filters: Price=$1.5680, Hurst=0.4603, 7d Volume=$23,819,891
# 2025-09-28 07:58:50,962 - INFO - Screening SHELL/USDT...
# 2025-09-28 07:58:50,962 - INFO - Progress: 221/423 - Found 9 valid pairs
# 2025-09-28 07:58:50,998 - INFO - Screening ACM/USDT...
# 2025-09-28 07:58:51,025 - INFO - Fetched 365 candles for SSV/USDT
# 2025-09-28 07:58:51,027 - INFO - Screening T/USDT...
# 2025-09-28 07:58:51,036 - INFO - Screening LUNC/USDT...
# 2025-09-28 07:58:51,074 - INFO - Screening SAHARA/USDT...
# 2025-09-28 07:58:51,103 - INFO - Screening IOTA/USDT...
# 2025-09-28 07:58:51,149 - INFO - Screening CETUS/USDT...
# 2025-09-28 07:58:51,177 - INFO - Screening MINA/USDT...
# 2025-09-28 07:58:51,223 - INFO - Screening FXS/USDT...
# 2025-09-28 07:58:51,253 - INFO - Screening PIXEL/USDT...
# 2025-09-28 07:58:51,253 - INFO - Progress: 230/423 pairs processed
# 2025-09-28 07:58:51,264 - INFO - Screening ATM/USDT...
# 2025-09-28 07:58:51,328 - INFO - Screening PORTO/USDT...
# 2025-09-28 07:58:51,387 - INFO - Fetched 365 candles for FXS/USDT
# 2025-09-28 07:58:51,389 - INFO - Screening SCR/USDT...
# 2025-09-28 07:58:51,403 - INFO - Screening COOKIE/USDT...
# 2025-09-28 07:58:51,462 - INFO - Fetched 365 candles for ATM/USDT
# 2025-09-28 07:58:51,463 - INFO - Screening ZRX/USDT...
# 2025-09-28 07:58:51,465 - INFO - Screening JASMY/USDT...
# 2025-09-28 07:58:51,484 - INFO - Screening LPT/USDT...
# 2025-09-28 07:58:51,541 - INFO - Screening MANA/USDT...
# 2025-09-28 07:58:51,560 - INFO - Screening BMT/USDT...
# 2025-09-28 07:58:51,616 - INFO - Screening ZIL/USDT...
# 2025-09-28 07:58:51,616 - INFO - Progress: 240/423 pairs processed
# 2025-09-28 07:58:51,636 - INFO - Screening NFP/USDT...
# 2025-09-28 07:58:51,681 - INFO - Fetched 365 candles for LPT/USDT
# 2025-09-28 07:58:51,684 - INFO - Screening RONIN/USDT...
# 2025-09-28 07:58:51,691 - INFO - Screening CYBER/USDT...
# 2025-09-28 07:58:51,763 - INFO - Screening ONG/USDT...
# 2025-09-28 07:58:51,837 - INFO - Screening NIL/USDT...
# 2025-09-28 07:58:51,845 - INFO - Screening BANANAS31/USDT...
# 2025-09-28 07:58:51,872 - INFO - Fetched 365 candles for CYBER/USDT
# 2025-09-28 07:58:51,874 - INFO - Screening AUCTION/USDT...
# 2025-09-28 07:58:52,115 - INFO - Fetched 365 candles for AUCTION/USDT
# 2025-09-28 07:58:52,119 - INFO - Progress: 250/423 pairs processed
# 2025-09-28 07:58:52,121 - INFO - Processing batch 6: 50 pairs
# 2025-09-28 07:58:52,124 - INFO - Screening CELO/USDT...
# 2025-09-28 07:58:52,125 - INFO - Screening GMT/USDT...
# 2025-09-28 07:58:52,125 - INFO - Screening ACH/USDT...
# 2025-09-28 07:58:52,207 - INFO - Screening MANTA/USDT...
# 2025-09-28 07:58:52,227 - INFO - Screening FIS/USDT...
# 2025-09-28 07:58:52,227 - INFO - Screening RED/USDT...
# 2025-09-28 07:58:52,283 - INFO - Screening METIS/USDT...
# 2025-09-28 07:58:52,303 - INFO - Screening NEWT/USDT...
# 2025-09-28 07:58:52,328 - INFO - Screening RARE/USDT...
# 2025-09-28 07:58:52,379 - INFO - Screening API3/USDT...
# 2025-09-28 07:58:52,413 - INFO - Screening ROSE/USDT...
# 2025-09-28 07:58:52,447 - INFO - Fetched 365 candles for METIS/USDT
# 2025-09-28 07:58:52,448 - INFO - Screening NXPC/USDT...
# 2025-09-28 07:58:52,454 - INFO - Screening AXS/USDT...
# 2025-09-28 07:58:52,454 - INFO - Progress: 260/423 pairs processed
# 2025-09-28 07:58:52,488 - INFO - Screening NOT/USDT...
# 2025-09-28 07:58:52,523 - INFO - Screening FLOW/USDT...
# 2025-09-28 07:58:52,563 - INFO - Screening BLUR/USDT...
# 2025-09-28 07:58:52,597 - INFO - Screening GLMR/USDT...
# 2025-09-28 07:58:52,634 - INFO - Fetched 365 candles for AXS/USDT
# 2025-09-28 07:58:52,636 - INFO - Screening UMA/USDT...
# 2025-09-28 07:58:52,639 - INFO - Screening KAVA/USDT...
# 2025-09-28 07:58:52,731 - INFO - Screening RAD/USDT...
# 2025-09-28 07:58:52,800 - INFO - Fetched 365 candles for UMA/USDT
# 2025-09-28 07:58:52,802 - INFO - Screening 1000CHEEMS/USDT...
# 2025-09-28 07:58:52,805 - INFO - Screening 1INCH/USDT...
# 2025-09-28 07:58:52,808 - INFO - Screening USTC/USDT...
# 2025-09-28 07:58:52,808 - INFO - Progress: 270/423 pairs processed
# 2025-09-28 07:58:52,875 - INFO - Screening VANRY/USDT...
# 2025-09-28 07:58:52,896 - INFO - Screening ASTR/USDT...
# 2025-09-28 07:58:52,897 - INFO - Screening A2Z/USDT...
# 2025-09-28 07:58:52,950 - INFO - Screening SUPER/USDT...
# 2025-09-28 07:58:52,971 - INFO - Screening MASK/USDT...
# 2025-09-28 07:58:52,991 - INFO - Screening QTUM/USDT...
# 2025-09-28 07:58:53,135 - INFO - Fetched 365 candles for MASK/USDT
# 2025-09-28 07:58:53,137 - INFO - Screening LQTY/USDT...
# 2025-09-28 07:58:53,158 - INFO - Fetched 365 candles for QTUM/USDT
# 2025-09-28 07:58:53,160 - INFO - Screening CTK/USDT...
# 2025-09-28 07:58:53,162 - INFO - Screening CKB/USDT...
# 2025-09-28 07:58:53,213 - INFO - Screening AXL/USDT...
# 2025-09-28 07:58:53,213 - INFO - Progress: 280/423 pairs processed
# 2025-09-28 07:58:53,234 - INFO - Screening FIDA/USDT...
# 2025-09-28 07:58:53,254 - INFO - Screening ANIME/USDT...
# 2025-09-28 07:58:53,289 - INFO - Screening SXT/USDT...
# 2025-09-28 07:58:53,310 - INFO - Screening DYM/USDT...
# 2025-09-28 07:58:53,331 - INFO - Screening COMP/USDT...
# 2025-09-28 07:58:53,365 - INFO - Screening PORTAL/USDT...
# 2025-09-28 07:58:53,387 - INFO - Screening YFI/USDT...
# 2025-09-28 07:58:53,439 - INFO - Screening CHESS/USDT...
# 2025-09-28 07:58:53,501 - INFO - Fetched 365 candles for COMP/USDT
# 2025-09-28 07:58:53,503 - INFO - Screening COTI/USDT...
# 2025-09-28 07:58:53,514 - INFO - Screening BANANA/USDT...
# 2025-09-28 07:58:53,514 - INFO - Progress: 290/423 pairs processed
# 2025-09-28 07:58:53,549 - INFO - Fetched 365 candles for YFI/USDT
# 2025-09-28 07:58:53,550 - INFO - Screening ACA/USDT...
# 2025-09-28 07:58:53,578 - INFO - Screening MAGIC/USDT...
# 2025-09-28 07:58:53,598 - INFO - Screening HAEDAL/USDT...
# 2025-09-28 07:58:53,625 - INFO - Screening PHB/USDT...
# 2025-09-28 07:58:53,653 - INFO - Screening XTZ/USDT...
# 2025-09-28 07:58:53,674 - INFO - Screening ILV/USDT...
# 2025-09-28 07:58:53,699 - INFO - Screening JST/USDT...
# 2025-09-28 07:58:53,773 - INFO - Progress: 300/423 pairs processed
# 2025-09-28 07:58:53,774 - INFO - Processing batch 7: 50 pairs
# 2025-09-28 07:58:53,774 - INFO - Screening BEL/USDT...
# 2025-09-28 07:58:53,775 - INFO - Screening CHR/USDT...
# 2025-09-28 07:58:53,776 - INFO - Screening QI/USDT...
# 2025-09-28 07:58:53,850 - INFO - Screening KSM/USDT...
# 2025-09-28 07:58:53,869 - INFO - Screening GTC/USDT...
# 2025-09-28 07:58:53,870 - INFO - Screening TRU/USDT...
# 2025-09-28 07:58:53,925 - INFO - Screening ENJ/USDT...
# 2025-09-28 07:58:53,944 - INFO - Screening PHA/USDT...
# 2025-09-28 07:58:53,965 - INFO - Screening ACE/USDT...
# 2025-09-28 07:58:53,999 - INFO - Screening ACX/USDT...
# 2025-09-28 07:58:54,020 - INFO - Screening CGPT/USDT...
# 2025-09-28 07:58:54,043 - INFO - Screening XVG/USDT...
# 2025-09-28 07:58:54,074 - INFO - Screening BAND/USDT...
# 2025-09-28 07:58:54,074 - INFO - Progress: 310/423 pairs processed
# 2025-09-28 07:58:54,097 - INFO - Screening ONE/USDT...
# 2025-09-28 07:58:54,120 - INFO - Screening CATI/USDT...
# 2025-09-28 07:58:54,150 - INFO - Screening DASH/USDT...
# 2025-09-28 07:58:54,172 - INFO - Screening NEXO/USDT...
# 2025-09-28 07:58:54,196 - INFO - Screening LUMIA/USDT...
# 2025-09-28 07:58:54,226 - INFO - Screening CVX/USDT...
# 2025-09-28 07:58:54,247 - INFO - Screening CTSI/USDT...
# 2025-09-28 07:58:54,269 - INFO - Screening VOXEL/USDT...
# 2025-09-28 07:58:54,300 - INFO - Screening SOPH/USDT...
# 2025-09-28 07:58:54,322 - INFO - Screening TNSR/USDT...
# 2025-09-28 07:58:54,323 - INFO - Progress: 320/423 pairs processed
# 2025-09-28 07:58:54,345 - INFO - Screening EURI/USDT...
# 2025-09-28 07:58:54,374 - INFO - Screening ATA/USDT...
# 2025-09-28 07:58:54,397 - INFO - Screening XVS/USDT...
# 2025-09-28 07:58:54,419 - INFO - Screening VELODROME/USDT...
# 2025-09-28 07:58:54,449 - INFO - Screening HMSTR/USDT...
# 2025-09-28 07:58:54,473 - INFO - Screening ARPA/USDT...
# 2025-09-28 07:58:54,493 - INFO - Screening QUICK/USDT...
# 2025-09-28 07:58:54,524 - INFO - Screening DODO/USDT...
# 2025-09-28 07:58:54,549 - INFO - Screening BICO/USDT...
# 2025-09-28 07:58:54,567 - INFO - Screening MBOX/USDT...
# 2025-09-28 07:58:54,567 - INFO - Progress: 330/423 pairs processed
# 2025-09-28 07:58:54,598 - INFO - Screening BTTC/USDT...
# 2025-09-28 07:58:54,625 - INFO - Screening AVA/USDT...
# 2025-09-28 07:58:54,643 - INFO - Screening RPL/USDT...
# 2025-09-28 07:58:54,674 - INFO - Screening OXT/USDT...
# 2025-09-28 07:58:54,700 - INFO - Screening RVN/USDT...
# 2025-09-28 07:58:54,719 - INFO - Screening AGLD/USDT...
# 2025-09-28 07:58:54,750 - INFO - Screening HIGH/USDT...
# 2025-09-28 07:58:54,775 - INFO - Screening MLN/USDT...
# 2025-09-28 07:58:54,796 - INFO - Screening NTRN/USDT...
# 2025-09-28 07:58:54,826 - INFO - Screening FLUX/USDT...
# 2025-09-28 07:58:54,826 - INFO - Progress: 340/423 pairs processed
# 2025-09-28 07:58:54,848 - INFO - Screening TUSD/USDT...
# 2025-09-28 07:58:54,870 - INFO - Screening LRC/USDT...
# 2025-09-28 07:58:54,901 - INFO - Screening SXP/USDT...
# 2025-09-28 07:58:54,923 - INFO - Screening ONT/USDT...
# 2025-09-28 07:58:54,944 - INFO - Screening TLM/USDT...
# 2025-09-28 07:58:54,976 - INFO - Screening HOT/USDT...
# 2025-09-28 07:58:54,998 - INFO - Screening STEEM/USDT...
# 2025-09-28 07:58:55,074 - INFO - Progress: 350/423 pairs processed
# 2025-09-28 07:58:55,075 - INFO - Processing batch 8: 50 pairs
# 2025-09-28 07:58:55,076 - INFO - Screening AUDIO/USDT...
# 2025-09-28 07:58:55,076 - INFO - Screening ORCA/USDT...
# 2025-09-28 07:58:55,077 - INFO - Screening DGB/USDT...
# 2025-09-28 07:58:55,154 - INFO - Screening POLYX/USDT...
# 2025-09-28 07:58:55,171 - INFO - Screening KNC/USDT...
# 2025-09-28 07:58:55,173 - INFO - Screening MOVR/USDT...
# 2025-09-28 07:58:55,228 - INFO - Screening BIGTIME/USDT...
# 2025-09-28 07:58:55,248 - INFO - Screening VTHO/USDT...
# 2025-09-28 07:58:55,248 - INFO - Screening STRAX/USDT...
# 2025-09-28 07:58:55,303 - INFO - Screening TFUEL/USDT...
# 2025-09-28 07:58:55,324 - INFO - Screening OSMO/USDT...
# 2025-09-28 07:58:55,342 - INFO - Screening AMP/USDT...
# 2025-09-28 07:58:55,382 - INFO - Screening DUSK/USDT...
# 2025-09-28 07:58:55,382 - INFO - Progress: 360/423 pairs processed
# 2025-09-28 07:58:55,398 - INFO - Screening GLM/USDT...
# 2025-09-28 07:58:55,417 - INFO - Screening DENT/USDT...
# 2025-09-28 07:58:55,455 - INFO - Screening ANKR/USDT...
# 2025-09-28 07:58:55,477 - INFO - Screening TKO/USDT...
# 2025-09-28 07:58:55,496 - INFO - Screening SYN/USDT...
# 2025-09-28 07:58:55,529 - INFO - Screening IOST/USDT...
# 2025-09-28 07:58:55,552 - INFO - Screening GAS/USDT...
# 2025-09-28 07:58:55,574 - INFO - Screening IDEX/USDT...
# 2025-09-28 07:58:55,605 - INFO - Screening MDT/USDT...
# 2025-09-28 07:58:55,628 - INFO - Screening HIVE/USDT...
# 2025-09-28 07:58:55,628 - INFO - Progress: 370/423 pairs processed
# 2025-09-28 07:58:55,649 - INFO - Screening OGN/USDT...
# 2025-09-28 07:58:55,683 - INFO - Screening UTK/USDT...
# 2025-09-28 07:58:55,703 - INFO - Screening SPELL/USDT...
# 2025-09-28 07:58:55,722 - INFO - Screening COS/USDT...
# 2025-09-28 07:58:55,759 - INFO - Screening RIF/USDT...
# 2025-09-28 07:58:55,779 - INFO - Screening FORTH/USDT...
# 2025-09-28 07:58:55,798 - INFO - Screening D/USDT...
# 2025-09-28 07:58:55,833 - INFO - Screening BAT/USDT...
# 2025-09-28 07:58:55,852 - INFO - Screening PIVX/USDT...
# 2025-09-28 07:58:55,872 - INFO - Screening SLP/USDT...
# 2025-09-28 07:58:55,872 - INFO - Progress: 380/423 pairs processed
# 2025-09-28 07:58:55,910 - INFO - Screening CELR/USDT...
# 2025-09-28 07:58:55,930 - INFO - Screening QKC/USDT...
# 2025-09-28 07:58:55,949 - INFO - Screening LSK/USDT...
# 2025-09-28 07:58:55,984 - INFO - Screening MTL/USDT...
# 2025-09-28 07:58:56,005 - INFO - Screening VIC/USDT...
# 2025-09-28 07:58:56,025 - INFO - Screening GNO/USDT...
# 2025-09-28 07:58:56,059 - INFO - Screening DATA/USDT...
# 2025-09-28 07:58:56,079 - INFO - Screening USDP/USDT...
# 2025-09-28 07:58:56,100 - INFO - Screening ARK/USDT...
# 2025-09-28 07:58:56,140 - INFO - Screening XEC/USDT...
# 2025-09-28 07:58:56,140 - INFO - Progress: 390/423 pairs processed
# 2025-09-28 07:58:56,154 - INFO - Screening ALCX/USDT...
# 2025-09-28 07:58:56,173 - INFO - Screening FLM/USDT...
# 2025-09-28 07:58:56,220 - INFO - Screening GNS/USDT...
# 2025-09-28 07:58:56,234 - INFO - Screening XNO/USDT...
# 2025-09-28 07:58:56,255 - INFO - Screening SC/USDT...
# 2025-09-28 07:58:56,295 - INFO - Screening NKN/USDT...
# 2025-09-28 07:58:56,313 - INFO - Screening ICX/USDT...
# 2025-09-28 07:58:56,388 - INFO - Progress: 400/423 pairs processed
# 2025-09-28 07:58:56,389 - INFO - Processing batch 9: 23 pairs
# 2025-09-28 07:58:56,390 - INFO - Screening POWR/USDT...
# 2025-09-28 07:58:56,392 - INFO - Screening FARM/USDT...
# 2025-09-28 07:58:56,392 - INFO - Screening FIO/USDT...
# 2025-09-28 07:58:56,467 - INFO - Screening WIN/USDT...
# 2025-09-28 07:58:56,486 - INFO - Screening WAN/USDT...
# 2025-09-28 07:58:56,487 - INFO - Screening STORJ/USDT...
# 2025-09-28 07:58:56,542 - INFO - Screening DF/USDT...
# 2025-09-28 07:58:56,564 - INFO - Screening WAXP/USDT...
# 2025-09-28 07:58:56,585 - INFO - Screening REI/USDT...
# 2025-09-28 07:58:56,618 - INFO - Screening IQ/USDT...
# 2025-09-28 07:58:56,638 - INFO - Screening BIFI/USDT...
# 2025-09-28 07:58:56,660 - INFO - Screening POND/USDT...
# 2025-09-28 07:58:56,692 - INFO - Screening ADX/USDT...
# 2025-09-28 07:58:56,692 - INFO - Progress: 410/423 pairs processed
# 2025-09-28 07:58:56,713 - INFO - Screening GHST/USDT...
# 2025-09-28 07:58:56,737 - INFO - Screening DCR/USDT...
# 2025-09-28 07:58:56,767 - INFO - Screening CVC/USDT...
# 2025-09-28 07:58:56,788 - INFO - Screening BNT/USDT...
# 2025-09-28 07:58:56,812 - INFO - Screening SCRT/USDT...
# 2025-09-28 07:58:56,841 - INFO - Screening SYS/USDT...
# 2025-09-28 07:58:56,863 - INFO - Screening ARDR/USDT...
# 2025-09-28 07:58:56,887 - INFO - Screening G/USDT...
# 2025-09-28 07:58:56,917 - INFO - Screening REQ/USDT...
# 2025-09-28 07:58:56,939 - INFO - Screening AEUR/USDT...
# 2025-09-28 07:58:56,939 - INFO - Progress: 420/423 pairs processed
# 2025-09-28 07:58:57,013 - INFO - Screening completed. 9 pairs passed filters.
# 2025-09-28 07:58:57,014 - INFO - Top 5 pairs selected.
# 2025-09-28 07:58:57,015 - INFO -
# ⏱️  Screening completed in 34.06 seconds
# 2025-09-28 07:58:57,016 - INFO - 📊 Found 5 pairs that passed all criteria
# 2025-09-28 07:58:57,016 - INFO -
# 🏆 TOP PAIRS FOR GRID TRADING:
# 2025-09-28 07:58:57,017 - INFO - ------------------------------------------------------------
# 2025-09-28 07:58:57,017 - INFO - 1. BNB/USDT
# 2025-09-28 07:58:57,018 - INFO -    💰 Price: $969.6000
# 2025-09-28 07:58:57,019 - INFO -    📈 Hurst: 0.4993
# 2025-09-28 07:58:57,020 - INFO -    💵 7d Volume: $2,644,735,811
# 2025-09-28 07:58:57,021 - INFO -    📊 7d Volume (base): 2,694,416.52
# 2025-09-28 07:58:57,021 - INFO -
# 2025-09-28 07:58:57,022 - INFO - 2. LTC/USDT
# 2025-09-28 07:58:57,022 - INFO -    💰 Price: $104.1000
# 2025-09-28 07:58:57,023 - INFO -    📈 Hurst: 0.4992
# 2025-09-28 07:58:57,024 - INFO -    💵 7d Volume: $255,793,697
# 2025-09-28 07:58:57,024 - INFO -    📊 7d Volume (base): 2,440,554.47
# 2025-09-28 07:58:57,025 - INFO -
# 2025-09-28 07:58:57,026 - INFO - 3. PAXG/USDT
# 2025-09-28 07:58:57,026 - INFO -    💰 Price: $3779.0000
# 2025-09-28 07:58:57,027 - INFO -    📈 Hurst: 0.4962
# 2025-09-28 07:58:57,027 - INFO -    💵 7d Volume: $145,482,578
# 2025-09-28 07:58:57,027 - INFO -    📊 7d Volume (base): 38,662.09
# 2025-09-28 07:58:57,028 - INFO -
# 2025-09-28 07:58:57,029 - INFO - 4. TIA/USDT
# 2025-09-28 07:58:57,029 - INFO -    💰 Price: $1.3890
# 2025-09-28 07:58:57,030 - INFO -    📈 Hurst: 0.4849
# 2025-09-28 07:58:57,031 - INFO -    💵 7d Volume: $95,738,625
# 2025-09-28 07:58:57,033 - INFO -    📊 7d Volume (base): 66,425,740.76
# 2025-09-28 07:58:57,033 - INFO -
# 2025-09-28 07:58:57,034 - INFO - 5. SANTOS/USDT
# 2025-09-28 07:58:57,035 - INFO -    💰 Price: $1.8810
# 2025-09-28 07:58:57,035 - INFO -    📈 Hurst: 0.4660
# 2025-09-28 07:58:57,036 - INFO -    💵 7d Volume: $25,775,827
# 2025-09-28 07:58:57,036 - INFO -    📊 7d Volume (base): 13,405,147.10
# 2025-09-28 07:58:57,037 - INFO -
# 2025-09-28 07:58:57,039 - INFO - Results saved to screening_results.json
# 2025-09-28 07:58:57,040 - INFO - 📋 SCREENING SUMMARY:
# 2025-09-28 07:58:57,041 - INFO -    Min Price: $1.0
# 2025-09-28 07:58:57,041 - INFO -    Min 7d Volume: $10,000,000
# 2025-09-28 07:58:57,042 - INFO -    Max Hurst: 0.5
# 2025-09-28 07:58:57,042 - INFO -    Data Period: 1 years
